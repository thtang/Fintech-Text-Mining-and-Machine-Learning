# %%
import pandas as pd
# 讀csv儅
df = pd.read_csv("Total Bond Market ETF List (82).csv",index_col='Symbol')

# %%
# 看前5筆數據
df.head()
# Out:
#                                            ETF Name Asset Class  \
# Symbol
# AGG            iShares Core U.S. Aggregate Bond ETF        Bond
# BND                  Vanguard Total Bond Market ETF        Bond
# BSV                    Vanguard Short-Term Bond ETF        Bond
# BNDX          Vanguard Total International Bond ETF        Bond
# MINT    PIMCO Enhanced Short Maturity Strategy Fund        Bond
#
#              Total Assets     YTD Avg Volume Previous Closing Price  \
# Symbol
# AGG     $57,071,132,686.00  0.45%  6,141,948                $106.97
# BND     $36,982,657,772.00  0.83%  2,943,894                 $79.67
# BSV     $23,944,569,102.00  0.42%  3,493,945                 $78.74
# BNDX    $13,673,292,937.00  0.98%  1,808,582                 $54.73
# MINT    $11,853,323,153.00  0.23%  1,462,739                $101.18
#
#        1-Day Change Inverse Leveraged  1 Week  \
# Symbol
# AGG          -0.46%      No        No   0.27%
# BND          -0.52%      No        No   0.52%
# BSV          -0.40%      No        No   0.24%
# BNDX         -0.11%      No        No   0.28%
# MINT         -0.22%      No        No  -0.12%
#
#                      ...                Returns Rating Volatility Rating  \
# Symbol               ...
# AGG                  ...                            A-                A-
# BND                  ...                            A-                B+
# BSV                  ...                            A-                 A
# BNDX                 ...                             A                B+
# MINT                 ...                             A                A-
#
#        Dividend Rating Concentration Rating ESG Score  \
# Symbol
# AGG                 B+                    A      6.14
# BND                 B+                   A+      6.13
# BSV                 C+                    A      6.34
# BNDX                C+                  NaN      6.26
# MINT                 A                   A+      4.89
#
#        ESG Score Peer Percentile (%) ESG Score Global Percentile (%)  \
# Symbol
# AGG                           73.97%                          71.15%
# BND                           71.92%                          70.97%
# BSV                           82.71%                          77.26%
# BNDX                          65.85%                          74.99%
# MINT                           9.77%                          30.15%
#
#        Carbon Intensity (Tons of CO2e / $M Sales) SRI Exclusion Criteria (%)  \
# Symbol
# AGG                                        333.04                      3.38%
# BND                                        355.94                      3.84%
# BSV                                        221.62                      3.04%
# BNDX                                       150.77                      1.90%
# MINT                                       262.78                      7.51%
#
#        Sustainable Impact Solutions (%)
# Symbol
# AGG                               1.05%
# BND                               1.22%
# BSV                               1.27%
# BNDX                              0.64%
# MINT                              1.53%
#
# [5 rows x 53 columns]

# %%
# 看Inception欄位
df[['Inception']].head()
# Out:
#          Inception
# Symbol
# AGG     2003-09-22
# BND     2007-04-10
# BSV     2007-04-10
# BNDX    2013-06-04
# MINT    2009-11-16

# %%
# 去除2015-12-31之後的etf
filtered_df=df[df['Inception']<='2015-12-31']

# %%
# 看去除之後的前5筆數據
filtered_df.head()
# Out:
#                                            ETF Name Asset Class  \
# Symbol
# AGG            iShares Core U.S. Aggregate Bond ETF        Bond
# BND                  Vanguard Total Bond Market ETF        Bond
# BSV                    Vanguard Short-Term Bond ETF        Bond
# BNDX          Vanguard Total International Bond ETF        Bond
# MINT    PIMCO Enhanced Short Maturity Strategy Fund        Bond
#
#              Total Assets     YTD Avg Volume Previous Closing Price  \
# Symbol
# AGG     $57,071,132,686.00  0.45%  6,141,948                $106.97
# BND     $36,982,657,772.00  0.83%  2,943,894                 $79.67
# BSV     $23,944,569,102.00  0.42%  3,493,945                 $78.74
# BNDX    $13,673,292,937.00  0.98%  1,808,582                 $54.73
# MINT    $11,853,323,153.00  0.23%  1,462,739                $101.18
#
#        1-Day Change Inverse Leveraged  1 Week  \
# Symbol
# AGG          -0.46%      No        No   0.27%
# BND          -0.52%      No        No   0.52%
# BSV          -0.40%      No        No   0.24%
# BNDX         -0.11%      No        No   0.28%
# MINT         -0.22%      No        No  -0.12%
#
#                      ...                Returns Rating Volatility Rating  \
# Symbol               ...
# AGG                  ...                            A-                A-
# BND                  ...                            A-                B+
# BSV                  ...                            A-                 A
# BNDX                 ...                             A                B+
# MINT                 ...                             A                A-
#
#        Dividend Rating Concentration Rating ESG Score  \
# Symbol
# AGG                 B+                    A      6.14
# BND                 B+                   A+      6.13
# BSV                 C+                    A      6.34
# BNDX                C+                  NaN      6.26
# MINT                 A                   A+      4.89
#
#        ESG Score Peer Percentile (%) ESG Score Global Percentile (%)  \
# Symbol
# AGG                           73.97%                          71.15%
# BND                           71.92%                          70.97%
# BSV                           82.71%                          77.26%
# BNDX                          65.85%                          74.99%
# MINT                           9.77%                          30.15%
#
#        Carbon Intensity (Tons of CO2e / $M Sales) SRI Exclusion Criteria (%)  \
# Symbol
# AGG                                        333.04                      3.38%
# BND                                        355.94                      3.84%
# BSV                                        221.62                      3.04%
# BNDX                                       150.77                      1.90%
# MINT                                       262.78                      7.51%
#
#        Sustainable Impact Solutions (%)
# Symbol
# AGG                               1.05%
# BND                               1.22%
# BSV                               1.27%
# BNDX                              0.64%
# MINT                              1.53%
#
# [5 rows x 53 columns]

# %%
# 得到要抓數據的symbols
etf_symbols = filtered_df.index[:]
etf_symbols
# Out:
# Index(['AGG', 'BND', 'BSV', 'BNDX', 'MINT', 'BIV', 'NEAR', 'SCHZ', 'FTSM',
#        'SPAB', 'BLV', 'TOTL', 'IUSB', 'GVI', 'ISTB', 'BOND', 'IAGG', 'FBND',
#        'VBND', 'AGGY', 'RAVI', 'ILTB', 'LDUR', 'FTSD', 'ULST', 'FLTB', 'XMPT',
#        'FIBR', 'MINC', 'GBF', 'AGZD', 'NFLT', 'HOLD', 'FCOR', 'BYLD', 'AGND',
#        'FWDB', 'KCNY', 'WYDE', 'SAGG'],
#       dtype='object', name='Symbol')

# %%
import requests
import re
import pandas as pd
from io import StringIO
import time

symbol = 'AGG'
#開始與結束時間
start_date = '1451491200'
end_date = '1552924800'
#使用regular expression找到對應的crumble
crumble_link = 'https://finance.yahoo.com/quote/{0}/history?p={0}'
crumble_regex = r'CrumbStore":{"crumb":"(.*?)"}'
cookie_regex = r'set-cookie: (.*?);'

link = crumble_link.format(symbol)
session = requests.Session()
response = session.get(link)

text = str(response.content)
match = re.search(crumble_regex,text)
crumbs = match.group(1)

cookie = session.cookies.get_dict()

url = 'https://query1.finance.yahoo.com/v7/finance/download/{0}?period1={1}&period2={2} \
&interval=1d&events=history&crumb={3}'.format(symbol,start_date,end_date,crumbs)
# 使用requests.get()得到數據
download=requests.get(url,cookies=cookie,timeout=5)
time.sleep(2)
# 讀csv檔案
df = pd.read_csv(StringIO(download.text)).set_index('Date')
# 調整col的名字
df = df[['Adj Close']]
df = df.rename(columns={'Adj Close':symbol})

# %%
df.head()
# Out:
#                    AGG
# Date
# 2015-12-30   99.345367
# 2015-12-31   99.612816
# 2016-01-04   99.575951
# 2016-01-05   99.622025
# 2016-01-06  100.000175

# %%
# 將symbols中的symbol對於的price都抓下來
for symbol in etf_symbols[1:]:
    link = crumble_link.format(symbol)
    session = requests.Session()
    response = session.get(link)

    text = str(response.content)
    match = re.search(crumble_regex,text)
    crumbs = match.group(1)

    cookie = session.cookies.get_dict()

    url = 'https://query1.finance.yahoo.com/v7/finance/download/{0}?period1={1}&period2={2} \
    &interval=1d&events=history&crumb={3}'.format(symbol,start_date,end_date,crumbs)
    
    try:
        download=requests.get(url,cookies=cookie,timeout=20)
        download.raise_for_status()
        time.sleep(5)

        new_df = pd.read_csv(StringIO(download.text)).set_index('Date')
        new_df = new_df[['Adj Close']]
        new_df = new_df.rename(columns={'Adj Close':symbol})
        df[symbol] = new_df;
    except:
        print(symbol+' failed.')
        pass
# Out:
# GBF failed.
# AGND failed.
# FWDB failed.

# %%
# 對於失敗的symbol再抓一次
failed_symbols = ['BNDX','IAGG','ULST','FLTB','MINC','AGND']
for symbol in failed_symbols:
    link = crumble_link.format(symbol)
    session = requests.Session()
    response = session.get(link)

    text = str(response.content)
    match = re.search(crumble_regex,text)
    crumbs = match.group(1)

    cookie = session.cookies.get_dict()

    url = 'https://query1.finance.yahoo.com/v7/finance/download/{0}?period1={1}&period2={2} \
    &interval=1d&events=history&crumb={3}'.format(symbol,start_date,end_date,crumbs)
    
    try:
        download=requests.get(url,cookies=cookie,timeout=20)
        download.raise_for_status()
        time.sleep(5)

        new_df = pd.read_csv(StringIO(download.text)).set_index('Date')
        new_df = new_df[['Adj Close']]
        new_df = new_df.rename(columns={'Adj Close':symbol})
        df[symbol] = new_df;
    except:
        print(symbol+' failed.')
        pass
# Out:
# ULST failed.

# %%
df.head()
# Out:
#                    AGG        BND        BSV       BNDX       MINT        BIV  \
# Date
# 2015-12-30   99.345367  74.030540  75.365646  49.085400  95.003563  75.977394
# 2015-12-31   99.612816  74.177483  75.413040  49.169086  94.984634  76.096497
# 2016-01-04   99.575951  74.140762  75.441475  49.271347  95.079063  76.243126
# 2016-01-05   99.622025  74.232628  75.431992  49.243462  95.079063  76.334732
# 2016-01-06  100.000175  74.563278  75.517281  49.429436  95.088493  76.646225
#
#                  NEAR       SCHZ       FTSM       SPAB    ...           MINC  \
# Date                                                      ...
# 2015-12-30  47.550110  47.479706  56.909050  26.094627    ...      44.449177
# 2015-12-31  47.569115  47.599861  56.918564  26.145035    ...      44.412453
# 2016-01-04  47.483524  47.636833  56.947105  26.167957    ...      44.403278
# 2016-01-05  47.550110  47.646095  56.947105  26.177118    ...      44.421631
# 2016-01-06  47.569115  47.784729  56.947105  26.296268    ...      44.485901
#
#                  AGZD       NFLT       HOLD       FCOR       BYLD       KCNY  \
# Date
# 2015-12-30  44.581268  21.101900  94.464401  42.777603  21.496824  32.227638
# 2015-12-31  44.739388  21.076359  94.464401  42.999287  21.523729  32.129230
# 2016-01-04  44.655678  21.050827  94.464401  43.111046  21.487864  31.970274
# 2016-01-05  44.730087  21.093390  94.464401  42.874809  21.523729  31.985418
# 2016-01-06  44.692879  21.042313  94.464401  42.965679  21.630402  31.764002
#
#                  WYDE       SAGG       AGND
# Date
# 2015-12-30  38.250000  32.416576  41.170654
# 2015-12-31  38.090000  32.416576  41.189316
# 2016-01-04  38.713001  32.269180  41.096062
# 2016-01-05  38.300999  32.308487  41.096062
# 2016-01-06  38.500000  32.229874  40.965500
#
# [5 rows x 38 columns]

# %%
FIBR_url = 'https://www.moneydj.com/ETF/X/xdjbcd/Basic0003BCD.xdjbcd?etfid=FIBR&b=20151231&c=20190319'

# %%
download_FIBR = requests.get(FIBR_url)
download_FIBR.status_code
# Out:
# 200

# %%
str = download_FIBR.text.split(' ')
date = str[0].split(',')
date  = [eachdate[:4]+'-'+eachdate[4:6]+'-'+eachdate[6:] for eachdate in date]
price = str[1].split(',')

# %%
df_FIBR = pd.DataFrame(data=price,index=date,columns=['FIBR'])

# %%
df_FIBR.head()
# Out:
#                FIBR
# 2015-12-31  96.6900
# 2016-01-04  96.6700
# 2016-01-05  96.7900
# 2016-01-06  96.9600
# 2016-01-07  96.9300

# %%
df['FIBR'] = df_FIBR;

# %%
df.head()
# Out:
#                    AGG        BND        BSV       BNDX       MINT        BIV  \
# Date
# 2015-12-30   99.345367  74.030540  75.365646  49.085400  95.003563  75.977394
# 2015-12-31   99.612816  74.177483  75.413040  49.169086  94.984634  76.096497
# 2016-01-04   99.575951  74.140762  75.441475  49.271347  95.079063  76.243126
# 2016-01-05   99.622025  74.232628  75.431992  49.243462  95.079063  76.334732
# 2016-01-06  100.000175  74.563278  75.517281  49.429436  95.088493  76.646225
#
#                  NEAR       SCHZ       FTSM       SPAB    ...           MINC  \
# Date                                                      ...
# 2015-12-30  47.550110  47.479706  56.909050  26.094627    ...      44.449177
# 2015-12-31  47.569115  47.599861  56.918564  26.145035    ...      44.412453
# 2016-01-04  47.483524  47.636833  56.947105  26.167957    ...      44.403278
# 2016-01-05  47.550110  47.646095  56.947105  26.177118    ...      44.421631
# 2016-01-06  47.569115  47.784729  56.947105  26.296268    ...      44.485901
#
#                  AGZD       NFLT       HOLD       FCOR       BYLD       KCNY  \
# Date
# 2015-12-30  44.581268  21.101900  94.464401  42.777603  21.496824  32.227638
# 2015-12-31  44.739388  21.076359  94.464401  42.999287  21.523729  32.129230
# 2016-01-04  44.655678  21.050827  94.464401  43.111046  21.487864  31.970274
# 2016-01-05  44.730087  21.093390  94.464401  42.874809  21.523729  31.985418
# 2016-01-06  44.692879  21.042313  94.464401  42.965679  21.630402  31.764002
#
#                  WYDE       SAGG       AGND
# Date
# 2015-12-30  38.250000  32.416576  41.170654
# 2015-12-31  38.090000  32.416576  41.189316
# 2016-01-04  38.713001  32.269180  41.096062
# 2016-01-05  38.300999  32.308487  41.096062
# 2016-01-06  38.500000  32.229874  40.965500
#
# [5 rows x 38 columns]

# %%
# 將抓到的data存成scv
df.to_csv('crawler_data.csv')
