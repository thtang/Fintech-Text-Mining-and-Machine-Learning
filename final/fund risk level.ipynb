# %%
import pandas as pd
import numpy as np
from collections import defaultdict
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns
import jieba
import requests
import nltk
from bs4 import BeautifulSoup
# %matplotlib inline

# %%
# get fund code
url = "http://www.yesfund.com.tw/w/wq/wq01.djhtm?fbclid=IwAR3x-JBkHxHawdA3dv3-PmFMtR-FP3LxT5nk1S-tvPaR3q9Zgz2jZbYdOwE"
response = requests.get(url).text
soup = BeautifulSoup(response, 'html.parser')

# %%
a_list = soup.find_all("a")
code_name_tup = []
code_name_tup_full = []
code_name_dict = {}
for a in a_list:
    code = a["href"].split("_")[1].split(".")[0].split("-")[0]
    name = a.text.split(" ")[-1]
    code_name_tup_full.append((code,name))
    if "累積型" in name:
        name = name.replace("累積型","累積類型")
    if "月配型" in name:
        name = name.replace("月配型","月配類型")
    if "季配型" in name:
        name = name.replace("季配型","季配類型")
    if "(台幣)" in name:
        name = name.replace("(台幣)","新臺幣計價")
    if "(人民幣)" in name:
        name = name.replace("(人民幣)","人民幣計價")
    name = name.split("(")[0]
    code_name_tup.append((code,name))
    try:
        code_name_dict[name] = code
    except:
        print(name)

# %%
code_name_tup_full
# Out:
# [('BFZICA', ''),
#  ('BFZICA', ''),
#  ('BFZICA', ''),
#  ('BFZICA', ''),
#  ('BFZICA', ''),
#  ('BFZICA', ''),
#  ('BFZICA', ''),
#  ('ACKH44', '野村全球不動產證券化基金-累積型(人民幣)(本基金之配息來源可能為本金)'),
#  ('ET008001', '不動產證券化型'),
#  ('ACKH43', '野村全球不動產證券化基金-月配型(人民幣)(本基金之配息來源可能為本金)'),
#  ('ET008001', '不動產證券化型'),
#  ('ACKH53', '野村動態配置多重資產基金-累積型(澳幣)(本基金有相當比重投資於非投資等級之高風險債券且配息來源可能為本金)'),
#  ('ET004005', '多重資產型'),
#  ('ACKH54', '野村動態配置多重資產基金-月配型(澳幣)(本基金有相當比重投資於非投資等級之高風險債券且配息來源可能為本金)'),
#  ('ET004005', '多重資產型'),
#  ('ACKH126', '野村六年目標到期新興市場債券基金(台幣)(本基金有相當比重投資於非投資等級之高風險債券)'),
#  ('ET005008', '債券型海外債券全球新興市場'),
#  ('ACKH116', '野村全球金融收益基金-月配型(台幣)(本基金配息來源可能為本金)'),
#  ('ET005003', '債券型海外債券投資等級'),
#  ('ACKH113', '野村全球金融收益基金-累積型(台幣)(本基金配息來源可能為本金)'),
#  ('ET005003', '債券型海外債券投資等級'),
#  ('ACKH96', '野村四年階梯到期新興市場債券基金-季配型(人民幣)(本基金有相當比重投資於非投資等級之高風險債券且配息來源可能為本金)'),
#  ('ET005003', '債券型海外債券投資等級'),
#  ('ACKH93', '野村四年階梯到期新興市場債券基金-累積型(人民幣)(本基金有相當比重投資於非投資等級之高風險債券且配息來源可能為本金)'),
#  ('ET005003', '債券型海外債券投資等級'),
#  ('ACIC15', '野村全球不動產證券化基金-累積型(台幣)(本基金之配息來源可能為本金)'),
#  ('ET008001', '不動產證券化型'),
#  ('ACIC1501', '野村全球不動產證券化基金-月配型(台幣)(本基金之配息來源可能為本金)'),
#  ('ET008001', '不動產證券化型'),
#  ('ACKH128', '野村六年階梯到期新興市場債券基金-累積型(台幣)(本基金有相當比重投資於非投資等級之高風險債券)'),
#  ('ET005008', '債券型海外債券全球新興市場'),
#  ('ACKH131', '野村六年階梯到期亞太新興債券基金-累積型(台幣)(本基金有相當比重投資於非投資等級之高風險債券且配息來源可能為本金)'),
#  ('ET005008', '債券型海外債券全球新興市場'),
#  ('ACKH132', '野村六年階梯到期亞太新興債券基金-年配型(台幣)(本基金有相當比重投資於非投資等級之高風險債券且配息來源可能為本金)'),
#  ('ET005008', '債券型海外債券全球新興市場'),
#  ('ACKH108', '野村五年階梯到期新興市場債券基金-累積型(人民幣)(本基金有相當比重投資於非投資等級之高風險債券且配息來源可能為本金)'),
#  ('ET005003', '債券型海外債券投資等級'),
#  ('ACKH111', '野村五年階梯到期新興市場債券基金-季配型(人民幣)(本基金有相當比重投資於非投資等級之高風險債券且配息來源可能為本金)'),
#  ('ET005003', '債券型海外債券投資等級'),
#  ('ACKH118', '野村全球金融收益基金-月配型(人民幣)(本基金配息來源可能為本金)'),
#  ('ET005003', '債券型海外債券投資等級'),
#  ('ACKH115', '野村全球金融收益基金-累積型(人民幣)(本基金配息來源可能為本金)'),
#  ('ET005003', '債券型海外債券投資等級'),
#  ('ACKH141', '野村六年目標到期亞太新興債券基金-累積型(台幣)(本基金有相當比重投資於非投資等級之高風險債券且配息來源可能為本金)'),
#  ('ET005008', '債券型海外債券全球新興市場'),
#  ('ACKH142', '野村六年目標到期亞太新興債券基金-年配型(台幣)(本基金有相當比重投資於非投資等級之高風險債券且配息來源可能為本金)'),
#  ('ET005008', '債券型海外債券全球新興市場'),
#  ('ACKH117', '野村全球金融收益基金-月配型(美元)(本基金配息來源可能為本金)'),
#  ('ET005003', '債券型海外債券投資等級'),
#  ('ACKH114', '野村全球金融收益基金-累積型(美元)(本基金配息來源可能為本金)'),
#  ('ET005003', '債券型海外債券投資等級'),
#  ('ACKH106', '野村五年階梯到期新興市場債券基金-累積型(台幣)(本基金有相當比重投資於非投資等級之高風險債券且配息來源可能為本金)'),
#  ('ET005003', '債券型海外債券投資等級'),
#  ('ACKH125', '野村六年目標到期新興市場債券基金(人民幣)(本基金有相當比重投資於非投資等級之高風險債券)'),
#  ('ET005008', '債券型海外債券全球新興市場'),
#  ('ACKH140', '野村六年階梯到期亞太新興債券基金-年配型(南非幣)(本基金有相當比重投資於非投資等級之高風險債券且配息來源可能為本金)'),
#  ('ET005008', '債券型海外債券全球新興市場'),
#  ('ACKH139', '野村六年階梯到期亞太新興債券基金-累積型(南非幣)(本基金有相當比重投資於非投資等級之高風險債券且配息來源可能為本金)'),
#  ('ET005008', '債券型海外債券全球新興市場'),
#  ('ACK
),
#  ('ET003002', '跨國投資股票型區域型'),
#  ('ACKH45', '野村全球高股息基金-季配型(人民幣)(本基金之配息來源可能為本金)'),
#  ('ET003001', '跨國投資股票型全球市場'),
#  ('ACKH46', '野村全球高股息基金-累積型(人民幣)(本基金之配息來源可能為本金)'),
#  ('ET003001', '跨國投資股票型全球市場'),
#  ('ACIC10', '野村全球高股息基金-累積型(台幣)(本基金之配息來源可能為本金)'),
#  ('ET003001', '跨國投資股票型全球市場'),
#  ('ACKH64', '野村日本領先基金'),
#  ('ET003003', '跨國投資股票型單一國家'),
#  ('ACIC1001', '野村全球高股息基金-季配型(台幣)(本基金之配息來源可能為本金)'),
#  ('ET003001', '跨國投資股票型全球市場'),
#  ('ACKH05', '野村鴻利基金'),
#  ('ET004001', '股票債券平衡型一般股票型'),
#  ('ACKH87', '野村亞太收益多重資產基金-累積型(人民幣)(本基金有相當比重投資於非投資等級之高風險債券且配息來源可能為本金)'),
#  ('ET004005', '多重資產型'),
#  ('ACKH90', '野村亞太收益多重資產基金-月配型(人民幣)(本基金有相當比重投資於非投資等級之高風險債券且配息來源可能為本金)'),
#  ('ET004005', '多重資產型'),
#  ('ACKH40', '野村歐洲中小成長基金(美元)'),
#  ('ET003002', '跨國投資股票型區域型'),
#  ('ACKH29', '野村台灣高股息基金'),
#  ('ET001007', '國內股票開放型價值型'),
#  ('ACKH86', '野村亞太收益多重資產基金-累積型(美元)(本基金有相當比重投資於非投資等級之高風險債券且配息來源可能為本金)'),
#  ('ET004005', '多重資產型'),
#  ('ACKH89', '野村亞太收益多重資產基金-月配型(美元)(本基金有相當比重投資於非投資等級之高風險債券且配息來源可能為本金)'),
#  ('ET004005', '多重資產型'),
#  ('ACIC05', '野村平衡基金'),
#  ('ET004001', '股票債券平衡型一般股票型'),
#  ('ACKH38', '野村歐洲中小成長基金(台幣)'),
#  ('ET003002', '跨國投資股票型區域型'),
#  ('ACIC29', '野村巴西基金'),
#  ('ET003003', '跨國投資股票型單一國家'),
#  ('ACIC14', '野村歐洲高股息基金-累積型(本基金之配息來源可能為本金)'),
#  ('ET003002', '跨國投資股票型區域型'),
#  ('ACIC1401', '野村歐洲高股息基金-季配型(本基金之配息來源可能為本金)'),
#  ('ET003002', '跨國投資股票型區域型'),
#  ('ACIC19', '野村全球生技醫療基金'),
#  ('ET003001', '跨國投資股票型全球市場'),
#  ('ACIC04', '野村成長基金'),
#  ('ET001005', '國內股票開放型一般股票型'),
#  ('ACKH07', '野村積極成長基金'),
#  ('ET001005', '國內股票開放型一般股票型'),
#  ('ACIC01', '野村優質基金'),
#  ('ET001005', '國內股票開放型一般股票型'),
#  ('ACIC32', '野村印度潛力基金'),
#  ('ET003003', '跨國投資股票型單一國家'),
#  ('ACIC26', '野村中國機會基金'),
#  ('ET003002', '跨國投資股票型區域型'),
#  ('ACIC18', '野村亞太高股息基金-累積型(台幣)(本基金之配息來源可能為本金)'),
#  ('ET003002', '跨國投資股票型區域型'),
#  ('ACIC1801', '野村亞太高股息基金-季配型(台幣)(本基金之配息來源可能為本金)'),
#  ('ET003002', '跨國投資股票型區域型'),
#  ('ACKH03', '野村台灣運籌基金'),
#  ('ET001005', '國內股票開放型一般股票型'),
#  ('AC0001', '野村鴻運基金'),
#  ('ET001005', '國內股票開放型一般股票型'),
#  ('ACIC08', '野村中小基金'),
#  ('ET001004', '國內股票開放型中小型'),
#  ('ACKH19', '野村高科技基金'),
#  ('ET001001', '國內股票開放型科技類'),
#  ('ACIC06', '野村e科技基金'),
#  ('ET001001', '國內股票開放型科技類'),
#  ('ACIC33', '野村印尼潛力基金'),
#  ('ET003003', '跨國投資股票型單一國家'),
#  ('ACKH162', '野村亞太複合高收益債基金-月配N類型(人民幣)(本基金主要係投資於非投資等級之高風險債券且配息來源可能為本金)'),
#  ('ET005004', '債券型高收益債券型'),
#  ('ACKH152', '野村全球金融收益基金-月配N類型(台幣)(本基金配息來源可能為本金)'),
#  ('ET005003', '債券型海外債券投資等級'),
#  ('ACKH157', '野村亞太新興債券基金-月配N類型(美元)(本基金有相當比重投資於非投資等級之高風險債券且配息來源可能為本金)'),
#  ('ET005009', '債券型海外債券亞洲新興市場'),
#  ('ACKH161', '野村亞太複合高收益債基金-月配N類型(美元)(本基金主要係投資於非投資等級之高風險債券且配息來源可能為本金)'),
#  ('ET005004', '債券型高收益債券型'),
#  ('ACKH154', '野村全球金融收益基金-月配N類型(人民幣)(本基金配息來源可能為本金)'),
#  ('ET005003', '債券型海外債券投資等級'),
#  ('ACKH158', '野村亞太新興債券基金-月配N類型(人民幣)(本基金有相當比重投資於非投資等級之高風險債券且配息來源可能為本金)'),
#  ('ET005009', '債券型海外債券亞洲新興市場'),
#  ('ACKH155', '野村亞太新興債券基金-累積N類型(台幣)(本基金有相當比重投資於非投資等級之高風險債券且配息來源可能為本金)'),
#  ('ET005009', '債券型海外債券亞洲新興市場'),
#  ('ACKH153', '野村全球金融收益基金-月配N類型(美元)(本基金配息來源可能為本金)'),
#  ('ET005003', '債券型海外債券投資等級'),
#  ('ACKH159', '野村亞太複合高收益債基金-累積N類型(台幣)(本基金主要係投資於非投資等級之高風險債券且配息來源可能為本金)'),
#  ('ET005004', '債券型高收益債券型'),
#  ('ACKH156', '野村亞太新興債券基金-月配N類型(台幣)(本基金有相當比重投資於非投資等級之高風險債券且配息來源可能為本金)'),
#  ('ET005009', '債券型海外債券亞洲新興市場'),
#  ('ACKH160', '野村亞太複合高收益債基金-月配N類型(台幣)(本基金主要係投資於非投資等級之高風險債券且配息來源可能為本金)'),
#  ('ET005004', '債券型高收益債券型'),
#  ('ACKH151', '野村全球金融收益基金-累積N類型(台幣)(本基金配息來源可能為本金)'),
#  ('ET005003', '債券型海外債券投資等級')]

# %%
invest = pd.read_excel("invest_data.xlsx")

# %%
pd.DataFrame(invest["基金簡稱"].unique()).to_csv("fund_name_code.csv", encoding="utf_8_sig", index=None)

# %%
code = []
invest_name = [n.replace(" ","") for n in invest["基金簡稱"].unique()]

# %%
code = []
for name in invest_name:
    if name in code_name_dict:
        code.append(code_name_dict[name])
    else:
        code.append('NaN')

# %%
pd.DataFrame(data={"name":invest["基金簡稱"].unique(),"code":code}).to_csv("fund_name_code.csv", encoding="utf_8_sig", index=None)

# %%
https://docs.google.com/spreadsheets/d/1K4VwQfRFwBDVnkHF7fEIGjDRfxegreY_9np0UwSG29k/edit?usp=sharing

# %% [markdown]
# # 計算 標準差 和 sharp ratio

# %%
fund_name_code = pd.read_excel("fund_name_code.xlsx")

# %%
fund_name_code.head()
# Out:
#                  name    code  sharp_ratio       std
# 0    野村優質基金-累積類型新臺幣計價  ACIC01     0.493156  0.167101
# 1            野村 e科技基金  ACIC06     0.414397  0.213106
# 2         野村中小基金-累積類型  ACIC08     0.494425  0.170284
# 3  野村全球高股息基金-累積型新臺幣計價  ACIC10     0.428375  0.112011
# 4          野村精選貨幣市場基金  ACKH22    18.697616  0.000149

# %%
len(price)
# Out:
# 183

# %%
# Out:
# [9.9321,
#  9.936,
#  9.9393,
#  9.9402,
#  9.9406,
#  9.9422,
#  9.9498,
#  9.9526,
#  9.953,
#  9.9567,
#  9.9577,
#  9.9587,
#  9.9599,
#  9.9602,
#  9.9603,
#  9.964,
#  9.9671,
#  9.9676]

# %%
# 爬取基金淨值
sharp_list = []
std_list = []
ES_list = []

for fund in fund_name_code["code"]:
    api = "https://www.moneydj.com/funddj/bcd/tBCDNavList.djbcd?a={}&B=2013-5-24&C=2019-5-24".format(fund)
    response = requests.get(api)
    content = response.text
    try:
        date = content.split(" ")[0].split(",")
        price = np.array([float(num) for num in content.split(" ")[1].split(",")])
        price_prev = np.roll(price,1)
        returns = ((price-price_prev)/price_prev)[1:]
        # 夏普率= [(每日報酬率平均值- 無風險利率) / (每日報酬的標準差)]x (252平方根)
        rf = 0.011/252
#         rf = 0
        mean = np.mean(returns)
        std = np.std(returns)
        sharp_ratio = ((mean-rf)/std)*252**0.5
        sharp_list.append(sharp_ratio)
        std_list.append(std*252**0.5)
        
        # 周資料
        price_prev = np.roll(price,7)
        weekly_returns = ((price-price_prev)/price_prev)[7:]
        ES = np.mean(sorted(weekly_returns)[:int(len(weekly_returns)*0.1)])
        ES_list.append(ES)
    except:
        sharp_list.append(0)
        std_list.append(0)
        ES_list.append(0)
        print(fund)
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan

# %%
fund_name_code["sharp_ratio"] = sharp_list
fund_name_code["std"] = std_list
fund_name_code["ES"] = ES_list

# %%
fund_name_code
# Out:
#                                name      code  sharp_ratio       std        ES
# 0                  野村優質基金-累積類型新臺幣計價    ACIC01     0.420179  0.167070 -0.051237
# 1                          野村 e科技基金    ACIC06     0.353621  0.213087 -0.068241
# 2                       野村中小基金-累積類型    ACIC08     0.421352  0.170263 -0.052389
# 3                野村全球高股息基金-累積型新臺幣計價    ACIC10     0.317579  0.112086 -0.034467
# 4                        野村精選貨幣市場基金    ACKH22   -55.294615  0.000149  0.000027
# 5                        野村全球生技醫療基金    ACIC19     0.410407  0.169253 -0.052038
# 6                     野村新興傘型之大俄羅斯基金       NaN     0.000000  0.000000  0.000000
# 7                          野村中國機會基金    ACIC26     0.311141  0.179978 -0.053455
# 8                野村全球美元投資級公司債基金-累積型       NaN     0.000000  0.000000  0.000000
# 9                      野村巴西證券投資信託基金       NaN     0.000000  0.000000  0.000000
# 10                    野村雙印傘型之印尼潛力基金       NaN     0.000000  0.000000  0.000000
# 11            野村亞太複合高收益債基金-累積型新臺幣計價    ACIC34     0.538302  0.030941 -0.011942
# 12                 野村全球短期收益基金-新台幣計價    ACKH65     0.843592  0.011357 -0.004197
# 13             野村多元收益平衡基金-累積類型新臺幣計價    ACKH66    -0.140338  0.049717 -0.019406
# 14             野村亞太新興債券基金-累積類型新臺幣計價    ACKH79     1.157836  0.021289 -0.007626
# 15                     野村環球基金-新臺幣計價    ACKH04     0.893942  0.118288 -0.034292
# 16                         野村台灣運籌基金    ACKH03     0.605605  0.159960 -0.048597
# 17            野村全球不動產證券化基金-累積型新臺幣計價    ACIC15     0.270846  0.106750 -0.035308
# 18                           野村新馬基金    ACKH09    -0.348137  0.097148 -0.033845
# 19                        野村台灣高股息基金    ACKH29     0.589223  0.137869 -0.043067
# 20                    野村雙印傘型之印度潛力基金    ACIC32     0.594051  0.164469 -0.054186
# 21             野村歐洲中小成長基金-累積類型新臺幣計價    ACKH38     0.063052  0.157677 -0.044234
# 22                         野村貨幣市場基金    ACKH10   -29.241672  0.000217  0.000074
# 23                           野村泰國基金    ACKH12    -0.167037  0.167843 -0.058474
# 24            野村亞太複合高收益債基金-月配型新臺幣計價    ACIC35    -1.322598  0.035843 -0.015113
# 25                         野村全球品牌基金    ACIC09     0.423219  0.136858 -0.038869
# 26                           野村鴻運基金    AC0001     0.316927  0.160189 -0.049593
# 27                          野村高科技基金    ACKH19     0.400610  0.211673 -0.067325
# 28                    野村日本領先基金-累積類型    ACKH64     0.233334  0.138493 -0.036274
# 29                 野村新興高收益債組合基金-月配型    ACIC31    -1.411186  0.030091 -0.012862
# ..                              ...       ...          ...       ...       ...
# 53                   野村鑫平衡組合基金-累積類型    ACIC12     0.509745  0.063187 -0.022035
# 54                 野村新興高收益債組合基金-累積型    ACIC30     0.299828  0.026516 -0.010807
# 55             野村亞太新興債券基金-配息類型新臺幣計價    ACKH82    -0.898629  0.026041 -0.010549
# 56              野村全球美元投資級公司債基金-月配類型       NaN     0.000000  0.000000  0.000000
# 57               野村全球高股息基金-季配型新臺幣計價  ACIC1001    -0.088699  0.115764 -0.036987
# 58           野村亞太收益多重資產基金-累積類型新臺幣計價    ACKH85    -0.687601  0.070995 -0.026606
# 59           野村亞太收益多重資產基金-月配類型新臺幣計價    ACKH88    -1.671247  0.075124 -0.030386
# 60           野村亞太收益多重資產基金-月配類型人民幣計價    ACKH90    -1.711178  0.087850 -0.036455
# 61              野村四年階梯到期新興債-累積新臺幣計價    ACKH91     0.020466  0.014376 -0.007011
# 62              野村四年階梯到期新興債-配息新臺幣計價    ACKH94    -0.875028  0.016386 -0.008069
# 63               野村四年階梯到期新興債-累積美元計價    ACKH92     0.924417  0.014055 -0.006553
# 64              野村四年階梯到期新興債-累積人民幣計價    ACKH93     1.485206  0.018703 -0.005767
# 65                  野村優質基金-S類型新臺幣計價       NaN     0.000000  0.000000  0.000000
# 66                  野村鑫全球債券組合基金-S類型       NaN     0.000000  0.000000  0.000000
# 67                    野村鑫平衡組合基金-S類型       NaN     0.000000  0.000000  0.000000
# 68                  野村環球基金-S類型新臺幣計價       NaN     0.000000  0.000000  0.000000
# 69                 野村新興高收益債組合基金-S類型       NaN     0.000000  0.000000  0.000000
# 70              野村環球高收益債基金-S類型新臺幣計價       NaN     0.000000  0.000000  0.000000
# 71            野村動態配置多重資產基金-S類型新臺幣計價       NaN     0.000000  0.000000  0.000000
# 72            野村核心配置多重資產基金-S類型新臺幣計價       NaN     0.000000  0.000000  0.000000
# 73  野村新興收益傘型基金之中國境內新興債券基金-累積類型新臺幣計?    ACKH97     1.027291  0.037172 -0.008043
# 74                     野村環球基金-人民幣計價    ACKH59     1.147359  0.127811 -0.038534
# 75      野村新興收益傘型基金之中國境內新興債券基金-人民幣計價    ACKH99     1.320842  0.017628 -0.005320
# 76  野村新興收益傘型基金之邊境市場高收益主權債基金-累積類型新臺?   ACKH100     0.255242  0.057926 -0.020656
# 77  野村新興收益傘型基金之邊境市場高收益主權債基金-月配類型新臺?   ACKH103    -0.580259  0.060892 -0.021147
# 78        野村新興收益傘型之五年階梯到期新興債基金-累積美元   ACKH107     4.894641  0.013529 -0.003738
# 79       野村新興收益傘型之五年階梯到期新興債基金-季配人民幣   ACKH111     1.300953  0.029532 -0.010191
# 80             野村全球金融收益基金-累積類型新臺幣計價   ACKH113     3.397691  0.014003 -0.002892
# 81             野村全球金融收益基金-月配類型新臺幣計價   ACKH116     0.954189  0.017103 -0.003619
# 82             野村全球金融收益基金-月配類型人民幣計價   ACKH118     1.017012  0.020613 -0.003510
#
# [83 rows x 5 columns]

# %%
fund_name_code.to_excel("fund_name_risk.xlsx", index=None,)
