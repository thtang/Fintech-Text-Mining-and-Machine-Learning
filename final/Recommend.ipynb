# %%
import pandas as pd
invest = pd.read_excel('invest_data.xlsx').fillna(0)
invest.head(100)
# Out:
#         客戶  基金                        基金簡稱 風險等級      金額
# 0   100066   1            野村優質基金-累積類型新臺幣計價  RR4    3000
# 1   100066   5                    野村 e科技基金  RR5   36079
# 2   100066   7                 野村中小基金-累積類型  RR5   40000
# 3   100066   9          野村全球高股息基金-累積型新臺幣計價  RR4    3000
# 4   100066  30                  野村精選貨幣市場基金  RR1       0
# 5   100066  37                  野村全球生技醫療基金  RR4    9617
# 6   100066  46               野村新興傘型之大俄羅斯基金  RR5   54273
# 7   100066  48                    野村中國機會基金  RR5  119385
# 8   100066  49          野村全球美元投資級公司債基金-累積型  RR2    5000
# 9   100066  51                野村巴西證券投資信託基金  RR5   88041
# 10  100066  55               野村雙印傘型之印尼潛力基金  RR5       0
# 11  100066  56       野村亞太複合高收益債基金-累積型新臺幣計價  RR4    3000
# 12  100066  94            野村全球短期收益基金-新台幣計價  RR2  232037
# 13  100066  95        野村多元收益平衡基金-累積類型新臺幣計價  RR3    3000
# 14  100066  A9        野村亞太新興債券基金-累積類型新臺幣計價  RR3    5000
# 15  100542  20                野村環球基金-新臺幣計價  RR4    3000
# 16  100558   7                 野村中小基金-累積類型  RR5    6000
# 17  100558  18                    野村台灣運籌基金  RR4    3000
# 18  100558  37                  野村全球生技醫療基金  RR4       0
# 19  100558  48                    野村中國機會基金  RR5    3000
# 20  100606   1            野村優質基金-累積類型新臺幣計價  RR4    3000
# 21  100606   9          野村全球高股息基金-累積型新臺幣計價  RR4    3000
# 22  100606  18                    野村台灣運籌基金  RR4    3000
# 23  100606  51                野村巴西證券投資信託基金  RR5    3000
# 24  100657   9          野村全球高股息基金-累積型新臺幣計價  RR4    5000
# 25  101140   1            野村優質基金-累積類型新臺幣計價  RR4    6000
# 26  101140   7                 野村中小基金-累積類型  RR5    8000
# 27  101140  14       野村全球不動產證券化基金-累積型新臺幣計價  RR4    3000
# 28  101140  18                    野村台灣運籌基金  RR4    3000
# 29  101140  24                      野村新馬基金  RR5    6000
# ..     ...  ..                         ...  ...     ...
# 70  102122  28                     野村高科技基金  RR5    3000
# 71  102122  36                   野村台灣高股息基金  RR4    3000
# 72  102122  93               野村日本領先基金-累積類型  RR4    3000
# 73  102123   1            野村優質基金-累積類型新臺幣計價  RR4    3000
# 74  102123   5                    野村 e科技基金  RR5    3000
# 75  102123  28                     野村高科技基金  RR5    3000
# 76  103813  53            野村新興高收益債組合基金-月配型  RR3   10000
# 77  104972   7                 野村中小基金-累積類型  RR5    3000
# 78  105001   7                 野村中小基金-累積類型  RR5    4000
# 79  105002   1            野村優質基金-累積類型新臺幣計價  RR4    8000
# 80  105002   5                    野村 e科技基金  RR5   10000
# 81  105002   7                 野村中小基金-累積類型  RR5    3000
# 82  105002  18                    野村台灣運籌基金  RR4   10000
# 83  105002  37                  野村全球生技醫療基金  RR4    3000
# 84  105002  48                    野村中國機會基金  RR5   10000
# 85  105002  54               野村雙印傘型之印度潛力基金  RR5    6000
# 86  105002  57       野村亞太複合高收益債基金-月配型新臺幣計價  RR4   10000
# 87  105002  67        野村歐洲中小成長基金-累積類型新臺幣計價  RR4    6000
# 88  105002  88  野村美利堅高收益債證券投資信託基金-配息型新臺幣計價  RR3   10000
# 89  105002  96        野村多元收益平衡基金-月配類型新臺幣計價  RR3   20000
# 90  105146   1            野村優質基金-累積類型新臺幣計價  RR4    3000
# 91  105146   5                    野村 e科技基金  RR5    3000
# 92  105146   7                 野村中小基金-累積類型  RR5    3000
# 93  105146   8                    野村全球品牌基金  RR4    3000
# 94  105146  18                    野村台灣運籌基金  RR4    3000
# 95  105146  37                  野村全球生技醫療基金  RR4    3000
# 96  105146  54               野村雙印傘型之印度潛力基金  RR5    3000
# 97  105146  88  野村美利堅高收益債證券投資信託基金-配息型新臺幣計價  RR3   30000
# 98  105146  96        野村多元收益平衡基金-月配類型新臺幣計價  RR3  200000
# 99  105188   3                      野村成長基金  RR4    3000
#
# [100 rows x 5 columns]

# %%
invest = invest.infer_objects()

# %%
invest.dtypes
# Out:
# 客戶       int64
# 基金      object
# 基金簡稱    object
# 風險等級    object
# 金額       int64
# dtype: object

# %%
fund = invest[['基金','基金簡稱','風險等級']].drop_duplicates('基金','first')

# %%
fund_dict = fund.set_index('基金').T.to_dict()

# %%
fund_dict[1]
# Out:
# {'基金簡稱': '野村優質基金-累積類型新臺幣計價', '風險等級': 'RR4'}

# %%
invest_sum = invest.groupby(by='客戶', as_index=True,sort=False).sum()

# %%
invest_sum.rename(columns={'金額':'總金額'},inplace=True)
invest_sum.head()
# Out:
#            總金額
# 客戶
# 100066  601432
# 100542    3000
# 100558   12000
# 100606   12000
# 100657    5000

# %%
invest = pd.merge(invest, invest_sum, on=['客戶'])

# %%
invest.head()
# Out:
#        客戶  基金                基金簡稱 風險等級     金額     總金額
# 0  100066   1    野村優質基金-累積類型新臺幣計價  RR4   3000  601432
# 1  100066   5            野村 e科技基金  RR5  36079  601432
# 2  100066   7         野村中小基金-累積類型  RR5  40000  601432
# 3  100066   9  野村全球高股息基金-累積型新臺幣計價  RR4   3000  601432
# 4  100066  30          野村精選貨幣市場基金  RR1      0  601432

# %%
invest['weight'] = invest['金額']/invest['總金額']

# %%
invest.head(20)
# Out:
#         客戶  基金                   基金簡稱 風險等級      金額     總金額    weight
# 0   100066   1       野村優質基金-累積類型新臺幣計價  RR4    3000  601432  0.004988
# 1   100066   5               野村 e科技基金  RR5   36079  601432  0.059988
# 2   100066   7            野村中小基金-累積類型  RR5   40000  601432  0.066508
# 3   100066   9     野村全球高股息基金-累積型新臺幣計價  RR4    3000  601432  0.004988
# 4   100066  30             野村精選貨幣市場基金  RR1       0  601432  0.000000
# 5   100066  37             野村全球生技醫療基金  RR4    9617  601432  0.015990
# 6   100066  46          野村新興傘型之大俄羅斯基金  RR5   54273  601432  0.090240
# 7   100066  48               野村中國機會基金  RR5  119385  601432  0.198501
# 8   100066  49     野村全球美元投資級公司債基金-累積型  RR2    5000  601432  0.008313
# 9   100066  51           野村巴西證券投資信託基金  RR5   88041  601432  0.146386
# 10  100066  55          野村雙印傘型之印尼潛力基金  RR5       0  601432  0.000000
# 11  100066  56  野村亞太複合高收益債基金-累積型新臺幣計價  RR4    3000  601432  0.004988
# 12  100066  94       野村全球短期收益基金-新台幣計價  RR2  232037  601432  0.385808
# 13  100066  95   野村多元收益平衡基金-累積類型新臺幣計價  RR3    3000  601432  0.004988
# 14  100066  A9   野村亞太新興債券基金-累積類型新臺幣計價  RR3    5000  601432  0.008313
# 15  100542  20           野村環球基金-新臺幣計價  RR4    3000    3000  1.000000
# 16  100558   7            野村中小基金-累積類型  RR5    6000   12000  0.500000
# 17  100558  18               野村台灣運籌基金  RR4    3000   12000  0.250000
# 18  100558  37             野村全球生技醫療基金  RR4       0   12000  0.000000
# 19  100558  48               野村中國機會基金  RR5    3000   12000  0.250000

# %%
from lightfm.data import Dataset

# %%
list(invest['客戶'])
# Out:
# [100066,
#  100066,
#  100066,
#  100066,
#  100066,
#  100066,
#  100066,
#  100066,
#  100066,
#  100066,
#  100066,
#  100066,
#  100066,
#  100066,
#  100066,
#  100542,
#  100558,
#  100558,
#  100558,
#  100558,
#  100606,
#  100606,
#  100606,
#  100606,
#  100657,
#  101140,
#  101140,
#  101140,
#  101140,
#  101140,
#  101140,
#  101140,
#  101140,
#  101140,
#  101140,
#  101140,
#  101140,
#  101140,
#  101140,
#  101140,
#  101140,
#  101140,
#  105582,
#  105582,
#  105582,
#  105582,
#  105582,
#  105582,
#  105582,
#  105582,
#  105582,
#  123855,
#  123855,
#  123855,
#  123855,
#  123855,
#  101150,
#  101150,
#  101150,
#  101150,
#  101150,
#  101150,
#  101150,
#  101150,
#  101150,
#  101150,
#  101275,
#  101275,
#  101275,
#  101275,
#  101275,
#  101275,
#  101275,
#  101614,
#  101614,
#  101976,
#  101976,
#  101976,
#  101976,
#  101976,
#  102122,
#  102122,
#  102122,
#  102122,
#  102122,
#  102122,
#  102122,
#  102123,
#  102123,
#  102123,
#  103813,
#  104972,
#  105001,
#  105002,
#  105002,
#  105002,
#  105002,
#  105002,
#  105002,
#  105002,
#  105002,
#  105002,
#  105002,
#  105002,
#  105146,
#  105146,
#  105146,
#  105146,
#  105146,
#  105146,
#  105146,
#  105146,
#  105146,
#  105188,
#  105188,
#  105188,
#  105188,
#  105188,
#  105188,
#  105292,
#  105292,
#  105292,
#  105292,
#  105314,
#  105314,
#  105417,
#  105417,
#  105417,
#  105417,
#  105417,
#  105482,
#  105482,
#  105482,
#  105482,
#  105482,
#  105482,
#  105482,
#  105482,
#  105528,
#  105528,
#  105528,
#  105528,
#  148472,
#  148472,
#  148472,
#  148472,
#  148472,
#  148472,
#  174992,
#  174992,
#  187080,
#  187080,
#  187080,
#  187080,
#  187080,
#  187080,
#  187080,
#  187080,
#  187080,
#  187080,
#  187080,
#  187080,
#  188357,
#  188357,
#  188357,
#  188357,
#  188357,
#  211951,
#  211951,
#  211951,
#  105619,
#  105983,
#  105983,
#  105983,
#  105983,
#  106130,
#  106130,
#  106130,
#  106131,
#  106131,
#  106443,
#  106456,
#  106456,
#  106456,
#  106456,
#  106456,
#  106456,
#  106456,
#  106456,
#  106595,
#  106595,
#  106760,
#  107182,
#  107182,
#  107182,
#  107182,
#  107182,
#  107182,
#  107182,
#  107182,
#  107182,
#  107415,
#  10751,
#  10751,
#  10751,
#  107573,
#  107573,
#  107573,
#  107574,
#  107636,
#  107636,
#  107636,
#  107636,
#  107636,
#  107636,
#  107636,
#  107636,
#  107636,
#  230374,
#  230374,
#  108323,
#  108323,
#  11065,
#  11065,
#  11065,
#  11065,
#  111638,
#  112286,
#  112286,
#  112657,
#  112657,
#  112657,
#  112657,
#  11271,
#  117370,
#  117370,
#  117370,
#  117370,
#  118091,
#  118091,
#  118091,
#  120041,
#  120041,
#  120041,
#  120041,
#  120220,
#  120220,
#  120220,
#  120411,
#  120411,
#  120458,
#  120458,
#  121863,
#  121863,
#  121863,
#  121863,
#  121863,
#  121863,
#  121863,
#  122885,
#  122885,
#  122885,
#  122885,
#  122885,
#  122885,
#  122885,
#  122885,
#  122885,
#  122885,
#  122885,
#  122885,
#  122885,
#  122885,
#  122885,
#  122885,
#  123447,
#  123656,
#  241563,
#  241563,
#  241563,
#  241563,
#  241563,
#  241563,
#  241563,
#  241563,
#  241563,
#  241563,
#  241563,
#  241563,
#  241563,
#  241563,
#  124,
#  124,
#  124,
#  124,
#  12416,
#  12416,
#  12416,
#  12416,
#  12434,
#  12434,
#  125516,
#  125516,
#  125516,
#  125516,
#  126622,
#  126622,
#  126622,
#  126622,
#  126622,
#  126622,
#  126622,
#  126927,
#  126927,
#  126927,
#  126927,
#  12876,
#  12876,
#  12924,
#  12924,
#  13015,
#  13015,
#  13016,
#  13016,
#  13016,
#  13107,
#  13107,
#  13107,
#  13107,
#  13107,
#  13107,
#  13107,
#  258885,
#  258885,
#  258885,
#  258885,
#  258885,
#  258885,
#  258885,
#  258885,
#  258885,
#  258885,
#  258885,
#  258885,
#  258885,
#  258885,
#  258885,
#  258885,
#  258885,
#  258885,
#  258885,
#  258885,
#  258885,
#  258885,
#  258885,
#  131553,
#  131553,
#  131553,
#  131553,
#  131553,
#  131553,
#  131553,
#  131553,
#  260131,
#  260131,
#  260131,
#  260131,
#  260131,
#  260131,
#  260131,
#  260131,
#  260131,
#  260131,
#  260131,
#  260131,
#  260131,
#  260131,
#  260131,
#  260131,
#  260131,
#  13192,
#  13192,
#  13290,
#  13290,
#  13347,
#  13347,
#  13347,
#  13347,
#  134380,
#  134380,
#  134380,
#  134380,
#  134799,
#  135485,
#  135485,
#  135485,
#  135485,
#  135485,
#  135485,
#  135485,
#  135485,
#  135485,
#  135485,
#  135485,
#  135485,
#  135485,
#  135485,
#  135485,
#  135485,
#  135485,
#  135485,
#  135485,
#  135485,
#  135485,
#  135485,
#  136408,
#  13694,
#  13694,
#  13694,
#  13694,
#  13694,
#  13694,
#  13694,
#  274315,
#  274315,
#  274315,
#  274315,
#  274315,
#  274315,
#  274315,
#  274315,
#  274315,
#  274315,
#  274315,
#  13886,
#  140809,
#  140809,
#  140809,
#  140809,
#  140809,
#  140809,
#  140809,
#  140809,
#  14086,
#  14086,
#  141728,
#  141728,
#  141728,
#  14173,
#  14173,
#  14173,
#  14173,
#  14173,
#  14173,
#  14173,
#  14173,
#  14173,
#  142891,
#  142891,
#  143389,
#  143389,
#  143389,
#  143389,
#  143389,
#  143389,
#  143389,
#  143726,
#  143726,
#  144414,
#  144414,
#  144414,
#  144414,
#  144414,
#  144414,
#  285511,
#  285511,
#  285511,
#  285511,
#  14481,
#  14481,
#  14481,
#  14481,
#  14481,
#  14481,
#  14631,
#  14631,
#  14631,
#  14631,
#  14631,
#  14631,
#  14631,
#  14631,
#  14631,
#  14631,
#  14631,
#  14631,
#  14631,
#  14631,
#  14631,
#  14631,
#  14631,
#  14631,
#  14631,
#  14631,
#  147735,
#  147735,
#  147827,
#  147827,
#  147827,
#  14784,
#  14784,
#  147951,
#  147951,
#  147951,
#  147951,
#  147951,
#  148221,
#  148221,
#  148221,
#  148221,
#  296560,
#  296560,
#  296560,
#  296560,
#  296560,
#  296560,
#  296560,
#  296560,
#  296560,
#  296560,
#  296560,
#  296560,
#  296560,
#  148580,
#  148633,
#  148633,
#  148633,
#  148633,
#  148633,
#  149029,
#  149029,
#  149029,
#  149029,
#  149029,
#  149029,
#  149029,
#  149287,
#  149287,
#  149287,
#  149287,
#  149287,
#  149287,
#  149287,
#  149287,
#  149287,
#  149324,
#  149324,
#  14934,
#  14934,
#  14934,
#  14934,
#  14934,
#  149559,
#  149559,
#  149559,
#  149559,
#  149559,
#  149559,
#  149559,
#  149559,
#  149559,
#  149559,
#  149559,
#  149559,
#  149559,
#  149559,
#  149559,
#  149559,
#  149559,
#  149559,
#  149559,
#  149559,
#  149559,
#  304817,
#  304817,
#  306751,
#  306751,
#  306751,
#  306751,
#  306751,
#  306751,
#  306751,
#  306751,
#  306751,
#  306751,
#  306751,
#  306751,
#  306751,
#  306751,
#  306751,
#  306751,
#  306751,
#  306751,
#  306751,
#  306751,
#  306751,
#  149961,
#  149961,
#  149961,
#  15008,
#  150296,
#  150296,
#  150296,
#  150296,
#  150674,
#  150674,
#  150674,
#  151399,
#  151399,
#  151399,
#  151399,
#  151399,
#  151399,
#  151399,
#  151399,
#  151399,
#  151399,
#  151399,
#  151399,
#  152722,
#  152722,
#  152722,
#  152722,
#  152912,
#  152912,
#  152912,
#  152912,
#  153928,
#  153928,
#  153928,
#  154361,
#  154361,
#  154607,
#  154607,
#  154918,
#  154918,
#  154918,
#  154926,
#  154926,
#  154926,
#  154926,
#  154926,
#  154926,
#  154926,
#  154926,
#  154926,
#  154926,
#  154926,
#  154926,
#  154926,
#  154956,
#  154972,
#  155148,
#  155148,
#  155148,
#  306871,
#  306871,
#  306871,
#  306871,
#  306871,
#  306871,
#  306871,
#  306871,
#  306871,
#  306871,
#  306871,
#  306871,
#  306871,
#  306871,
#  306871,
#  306871,
#  308078,
#  308078,
#  308078,
#  308078,
#  155461,
#  155461,
#  155461,
#  155461,
#  155461,
#  155461,
#  155660,
#  155660,
#  155969,
#  155969,
#  155969,
#  155969,
#  157097,
#  157097,
#  15746,
#  157523,
#  157523,
#  157523,
#  157523,
#  157523,
#  158075,
#  158100,
#  158100,
#  158533,
#  158533,
#  158599,
#  158599,
#  158599,
#  158599,
#  158599,
#  158599,
#  158599,
#  158599,
#  158599,
#  158667,
#  159058,
#  159058,
#  159058,
#  159728,
#  159728,
#  160426,
#  160426,
#  160426,
#  160426,
#  161138,
#  161201,
#  161201,
#  161201,
#  161201,
#  161201,
#  161201,
#  161201,
#  161461,
#  161461,
#  161461,
#  161461,
#  161917,
#  161917,
#  161917,
#  161917,
#  161917,
#  162023,
#  162023,
#  162023,
#  162023,
#  162023,
#  162128,
#  162128,
#  162128,
#  162128,
#  162128,
#  162128,
#  162128,
#  162128,
#  162128,
#  162128,
#  162128,
#  162128,
#  162128,
#  162128,
#  162128,
#  162128,
#  162128,
#  162128,
#  162128,
#  162128,
#  162128,
#  308266,
#  308266,
#  308266,
#  308266,
#  308266,
#  308266,
#  308266,
#  308266,
#  308266,
#  162220,
#  162220,
#  162220,
#  162443,
#  162443,
#  162443,
#  162443,
#  162443,
#  162443,
#  162443,
#  162443,
#  162443,
#  162443,
#  162443,
#  162443,
#  162443,
#  162443,
#  162443,
#  162443,
#  162443,
#  162443,
#  162443,
#  162971,
#  162971,
#  162971,
#  162971,
#  163081,
#  163326,
#  163326,
#  163326,
#  163326,
#  163326,
#  163326,
#  163326,
#  163326,
#  163326,
#  163431,
#  163431,
#  163431,
#  163431,
#  163431,
#  163431,
#  163431,
#  163431,
#  163431,
#  310729,
#  310729,
#  163662,
#  163662,
#  163662,
#  164662,
#  164662,
#  164662,
#  164662,
#  164662,
#  164662,
#  164662,
#  310879,
#  310879,
#  310879,
#  310879,
#  310879,
#  310879,
#  310879,
#  164735,
#  164735,
#  164735,
#  1649,
#  1649,
#  1649,
#  164970,
#  164970,
#  164970,
#  164970,
#  165239,
#  165239,
#  165259,
#  165259,
#  165259,
#  165270,
#  165491,
#  165491,
#  165491,
#  165491,
#  165491,
#  165491,
#  165491,
#  165491,
#  165491,
#  165491,
#  165491,
#  165491,
#  165491,
#  165491,
#  165491,
#  165951,
#  165951,
#  165959,
#  165982,
#  165982,
#  166225,
#  166225,
#  166225,
#  166225,
#  166225,
#  166225,
#  166225,
#  166225,
#  166225,
#  166225,
#  166225,
#  166225,
#  166225,
#  166225,
#  312680,
#  312680,
#  312680,
#  166436,
#  166592,
#  166592,
#  166592,
#  166592,
#  166592,
#  166592,
#  166592,
#  166592,
#  166592,
#  312941,
#  312941,
#  312941,
#  312941,
#  312941,
#  166852,
#  167212,
#  167212,
#  167212,
#  167212,
#  167212,
#  167212,
#  167262,
#  167262,
#  167262,
#  167262,
#  167262,
#  167262,
#  312950,
#  312950,
#  312950,
#  312950,
#  312950,
#  312950,
#  312950,
#  312950,
#  312950,
#  312950,
#  312950,
#  312950,
#  314178,
#  314178,
#  314178,
#  314178,
#  314320,
#  314320,
#  314320,
#  314320,
#  314320,
#  314320,
#  314320,
#  314320,
#  167376,
#  167376,
#  167376,
#  167376,
#  167376,
#  167376,
#  167376,
#  167396,
#  167396,
#  167396,
#  167396,
#  167396,
#  167396,
#  167396,
#  167396,
#  167396,
#  167396,
#  167397,
#  167397,
#  167892,
#  167892,
#  167892,
#  167892,
#  315989,
#  315989,
#  315989,
#  167965,
#  167965,
#  167965,
#  167965,
#  167965,
#  167965,
#  167965,
#  168008,
#  168284,
#  168440,
#  168766,
#  168766,
#  168766,
#  169021,
#  169024,
#  169133,
#  169133,
#  169133,
#  169183,
#  169183,
#  16960,
#  16960,
#  16960,
#  169961,
#  ...]

# %%
data = zip(list(invest['客戶']),list(invest['基金']),list(invest['weight']))

# %%
dataset = Dataset()
user_id = list(set(invest['客戶']))
item_id = list(set(invest['基金']))
dataset.fit(user_id,item_id)
COO = dataset.build_interactions(data)

# %%
id_map = dataset.mapping()

# %%
user_map = id_map[0]
internal_item_map = id_map[2]

# %%
user_map[123855]
# Out:
# 181

# %%
item_map={}
for k in internal_item_map.keys():
    v = internal_item_map[k]
    item_map[v]=k

# %%
item_map[55]
# Out:
# 88

# %%
from lightfm import LightFM
model = LightFM(loss='warp')
model.fit(COO[0],sample_weight=COO[1],epochs=100,num_threads=4)

# %%
query_id = 105417

# %%
import numpy as np
scores = model.predict(user_map[105417], np.arange(83))

# %%
np.argsort(-scores)
# Out:
# array([24, 57,  5, 20,  0, 16,  3, 35,  1, 18, 27, 15,  2, 17, 82, 54, 46,
#        30, 41, 59, 42, 13, 75, 55, 43, 26, 62, 12, 21, 78,  4, 19, 23, 52,
#        29, 14, 22, 68, 32,  7, 10, 31, 38, 34, 11, 28, 40, 77, 60, 63, 53,
#        33, 74, 50,  6, 56, 37,  9, 64, 80, 49, 69, 48, 81, 70, 61, 25, 45,
#        65, 66, 36, 39, 76, 73, 67, 72, 51, 47,  8, 79, 71, 58, 44],
#       dtype=int64)

# %%
top_items = item_map['item_labels'][np.argsort(-scores)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-186-2aac17a79fc6> in <module>
# ----> 1 top_items = item_map['item_labels'][np.argsort(-scores)]
#
# KeyError: 'item_labels'

# %%
COO[0].shape
# Out:
# (1522, 83)

# %%
def recommendation(model, data, user_ids,user_map,item_map):
    n_users, n_items = data.shape
    for user_id in user_ids:
        known_positives = invest[invest['客戶']==user_id]
        scores = model.predict(user_map[user_id], np.arange(n_items))
        top_items = []
        count = 0
        known_positive_list = list(known_positives['基金'])
        for x in np.argsort(-scores):
            if(item_map[x] not in known_positive_list):
                top_items.append(item_map[x])
                count += 1
                if(count==3):
                    break
        print("User %s" % user_id)
        print("Known positives:")
        print(known_positives[['客戶','基金','基金簡稱','風險等級','金額']].head())
        print("Recommended:")
        for x in top_items[:3]:
            print(x,':',fund_dict[x])

# %%
recommendation(model,COO[0],[query_id],user_map,item_map)
# Out:
# User 105417
# Known positives:
#          客戶  基金              基金簡稱 風險等級    金額
# 125  105417   1  野村優質基金-累積類型新臺幣計價  RR4  3000
# 126  105417   7       野村中小基金-累積類型  RR5  3000
# 127  105417  23          野村積極成長基金  RR4  3000
# 128  105417  28           野村高科技基金  RR5  3000
# 129  105417  93     野村日本領先基金-累積類型  RR4  3000
# Recommended:
# 19 : {'基金簡稱': '野村鴻運基金', '風險等級': 'RR4'}
# 5 : {'基金簡稱': '野村 e科技基金', '風險等級': 'RR5'}
# 48 : {'基金簡稱': '野村中國機會基金', '風險等級': 'RR5'}
