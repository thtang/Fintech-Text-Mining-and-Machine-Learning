# %%
import pandas as pd
import numpy as np
from collections import defaultdict
import matplotlib.pyplot as plt
from collections import Counter

# %%
risk_qa = pd.read_excel("risk_data.xlsx")

# %%
risk_qa.head(40)
# Out:
#       客戶編號  風險等級 風險等級分類                 適性評量填寫日期     適性版號 題目序號  \
# 0   261909     5    積極型  2018-10-30 22:54:34.523  201809A   A0
# 1   261909     5    積極型  2018-10-30 22:54:34.523  201809A  A01
# 2   261909     5    積極型  2018-10-30 22:54:34.523  201809A  A02
# 3   261909     5    積極型  2018-10-30 22:54:34.523  201809A  A03
# 4   261909     5    積極型  2018-10-30 22:54:34.523  201809A  A03
# 5   261909     5    積極型  2018-10-30 22:54:34.523  201809A  A04
# 6   261909     5    積極型  2018-10-30 22:54:34.523  201809A  A05
# 7   261909     5    積極型  2018-10-30 22:54:34.523  201809A  A06
# 8   261909     5    積極型  2018-10-30 22:54:34.523  201809A  A07
# 9   261909     5    積極型  2018-10-30 22:54:34.523  201809A  A08
# 10  261909     5    積極型  2018-10-30 22:54:34.523  201809A  A08
# 11  261909     5    積極型  2018-10-30 22:54:34.523  201809A  A08
# 12  261909     5    積極型  2018-10-30 22:54:34.523  201809A  A09
# 13  261909     5    積極型  2018-10-30 22:54:34.523  201809A  A09
# 14  261909     5    積極型  2018-10-30 22:54:34.523  201809A  A10
# 15  261909     5    積極型  2018-10-30 22:54:34.523  201809A  A11
# 16  261909     5    積極型  2018-10-30 22:54:34.523  201809A  A12
# 17  261909     5    積極型  2018-10-30 22:54:34.523  201809A  A13
# 18  261909     5    積極型  2018-10-30 22:54:34.523  201809A  A14
# 19  261909     5    積極型  2018-10-30 22:54:34.523  201809A  B01
# 20  261909     5    積極型  2018-10-30 22:54:34.523  201809A  B02
# 21  261909     5    積極型  2018-10-30 22:54:34.523  201809A  B02
# 22  261909     5    積極型  2018-10-30 22:54:34.523  201809A  B02
# 23  261909     5    積極型  2018-10-30 22:54:34.523  201809A  B02
# 24  261909     5    積極型  2018-10-30 22:54:34.523  201809A  B02
# 25  261909     5    積極型  2018-10-30 22:54:34.523  201809A  B03
# 26  261909     5    積極型  2018-10-30 22:54:34.523  201809A  B03
# 27  261909     5    積極型  2018-10-30 22:54:34.523  201809A  B03
# 28  261909     5    積極型  2018-10-30 22:54:34.523  201809A  B04
# 29  261909     5    積極型  2018-10-30 22:54:34.523  201809A  B05
# 30  261909     5    積極型  2018-10-30 22:54:34.523  201809A  B06
# 31  261909     5    積極型  2018-10-30 22:54:34.523  201809A  B07
# 32  269963     5    積極型  2018-10-24 09:49:10.847  201809A   A0
# 33  269963     5    積極型  2018-10-24 09:49:10.847  201809A  A01
# 34  269963     5    積極型  2018-10-24 09:49:10.847  201809A  A02
# 35  269963     5    積極型  2018-10-24 09:49:10.847  201809A  A03
# 36  269963     5    積極型  2018-10-24 09:49:10.847  201809A  A03
# 37  269963     5    積極型  2018-10-24 09:49:10.847  201809A  A04
# 38  269963     5    積極型  2018-10-24 09:49:10.847  201809A  A05
# 39  269963     5    積極型  2018-10-24 09:49:10.847  201809A  A06
#
#                                  KYC_QUESTION  ANS_ORDER  \
# 0                               是否為其他國家稅務居住者?          1
# 1                                      職業／行業別          8
# 2                                          職務          1
# 3                                        任職單位          1
# 4                                        任職單位          2
# 5                                          學歷          4
# 6                                        婚姻狀況          3
# 7                                    外國人士居留目的          1
# 8                                    與政治人物之關係          1
# 9                                   投資目的(可複選)          1
# 10                                  投資目的(可複選)          3
# 11                                  投資目的(可複選)          5
# 12                                投資資金來源(可複選)          2
# 13                                投資資金來源(可複選)          3
# 14                              家庭年收入(單位：新台幣)          2
# 15                             家庭年支出 (單位：新台幣)          1
# 16                         預計(單筆)投資金額(單位：新台幣)          1
# 17                                  是否為信託之受託人          1
# 18                                 特殊身分客戶風險確認          4
# 19                                  您屬於哪個年齡層?          3
# 20      您是否(曾經持有)以下任何投資產品?(可複選，計分時僅計算分數最高之答案)          1
# 21      您是否(曾經持有)以下任何投資產品?(可複選，計分時僅計算分數最高之答案)          2
# 22      您是否(曾經持有)以下任何投資產品?(可複選，計分時僅計算分數最高之答案)          3
# 23      您是否(曾經持有)以下任何投資產品?(可複選，計分時僅計算分數最高之答案)          4
# 24      您是否(曾經持有)以下任何投資產品?(可複選，計分時僅計算分數最高之答案)          5
# 25         您對於基金類型的投資標的偏好?(可複選，計分時僅計算分數最高之答案)          3
# 26         您對於基金類型的投資標的偏好?(可複選，計分時僅計算分數最高之答案)          4
# 27         您對於基金類型的投資標的偏好?(可複選，計分時僅計算分數最高之答案)          5
# 28     若緊急突發事件發生時，請問您所持有的備用金相當於您幾個月的家庭開銷?(單選)          5
# 29                            您習慣的基金投資方式?(單選)          4
# 30   就長期投資而言，您所期望平均年投資報酬率是多少?(以投資100萬元為例)(單選)          4
# 31  就長期投資而言，您所能承受每年最大投資損失是多少?(以投資100萬元為例)(單選)          4
# 32                              是否為其他國家稅務居住者?          1
# 33                                     職業／行業別          6
# 34                                         職務          1
# 35                                       任職單位          1
# 36                                       任職單位          2
# 37                                         學歷          4
# 38                                       婚姻狀況          2
# 39                                   外國人士居留目的          1
#
#                                 ANS_ITEM  答題得分 客戶職業與任職部門     AGENT代碼
# 0                                    1.否     0       NaN  9999999999
# 1                                 8.退休人士     0       NaN  9999999999
# 2                                 1.基層職員     0       NaN  9999999999
# 3                              1.任職公司／機構     0        寶豐  9999999999
# 4                                 2.任職部門     0        營建  9999999999
# 5                                   4.大學     0       NaN  9999999999
# 6                            3.不同意提供本項資料     0       NaN  9999999999
# 7                                1.為本國人士     0       NaN  9999999999
# 8                              1.與政治人物無關     0       NaN  9999999999
# 9                               1.閒置資金運用     0       NaN  9999999999
# 10                               3.儲備退休金     0       NaN  9999999999
# 11                            5.追求長期投資報酬     0       NaN  9999999999
# 12                                 2.退休金     0       NaN  9999999999
# 13                                3.投資收益     0       NaN  9999999999
# 14                       2.50萬元(含)~100萬元     0       NaN  9999999999
# 15                              1.50萬元以下     0       NaN  9999999999
# 16                             1.100萬元以下     0       NaN  9999999999
# 17                            1.不是信託之受託人     0       NaN  9999999999
# 18                                4.以上皆非     0       NaN  9999999999
# 19                              3.56~65歲     3       NaN  9999999999
# 20                1.現金、存款、定存、貨幣型基金與保本型基金     1       NaN  9999999999
# 21                        2.債券、投資等級之債券基金     2       NaN  9999999999
# 22      3.外幣存款、非投資等級之債券基金、平衡型基金、新興市場債券基金     3       NaN  9999999999
# 23          4.股票、全球股票基金、歐美成熟國家股票基金、投資型保單     4       NaN  9999999999
# 24           5.新興市場股票基金、單一新興國家股票基金、衍生性商品     5       NaN  9999999999
# 25      3.平衡型基金、已開發國家非投資級公司債券基金、新興市場債券基金     3       NaN  9999999999
# 26        4.全球股票基金、歐美成熟國家股票基金、大中華或亞太股票基金     4       NaN  9999999999
# 27  5.新興市場股票基金、單一新興國家股票基金、產業類股型基金、店頭市場基金     5       NaN  9999999999
# 28                               5.超過9個月     5       NaN  9999999999
# 29                4.單筆(不含貨幣型基金)和定時定額兩者都有     4       NaN  9999999999
# 30                4.9%~12%(每年希望獲利9~12萬元)     4       NaN  9999999999
# 31               4.9%~12%(每年可接受損失9~12萬元)     4       NaN  9999999999
# 32                                   1.否     0       NaN  9999999999
# 33                               6.醫療服務業     0       NaN  9999999999
# 34                                1.基層職員     0       NaN  9999999999
# 35                             1.任職公司／機構     0      桃園醫院  9999999999
# 36                                2.任職部門     0        內科  9999999999
# 37                                  4.大學     0       NaN  9999999999
# 38                             2.已婚(子女數)     0         2  9999999999
# 39                               1.為本國人士     0       NaN  9999999999

# %%
uni_id = np.unique(risk_qa["客戶編號"])

# %%
uni_id.shape
# Out:
# (1884,)

# %%
attr_dict = defaultdict(lambda: defaultdict(list))
max_ans_dict = defaultdict(int) # record max answer num for each question (for one-hot array)

for index, row in risk_qa.iterrows():
    attr_dict[row["客戶編號"]]['QA風險等級'] = row['風險等級']
    if str(row['客戶職業與任職部門'])=='nan':
        attr_dict[row["客戶編號"]][row["題目序號"]].append(row["ANS_ORDER"])
    else:
        attr_dict[row["客戶編號"]][row["題目序號"]].append(str(row["ANS_ORDER"])+":"+row["客戶職業與任職部門"])
    if max_ans_dict[row["題目序號"]]<row["ANS_ORDER"]:
        max_ans_dict[row["題目序號"]] = row["ANS_ORDER"]

# %%
for user in attr_dict:
    for q in attr_dict[user]:
        if q != 'QA風險等級':
            attr_dict[user][q] = list(set(attr_dict[user][q]))

# %%
ans = pd.DataFrame.from_dict(attr_dict).transpose()

# %%
ans.index.name = '客戶'

# %%
ans.head()
# Out:
#          A0  A01  A02              A03  A04    A05  A06  A07  \
# 客戶
# 261909  [1]  [8]  [1]     [1:寶豐, 2:營建]  [4]    [3]  [1]  [1]
# 269963  [1]  [6]  [1]   [2:內科, 1:桃園醫院]  [4]  [2:2]  [1]  [1]
# 270057  [1]  [3]  [1]   [2:信用卡部, 1:渣打]  [4]  [2:1]  [1]  [1]
# 270507  [1]  [5]  [2]  [2:000, 1:0000]  [4]  [2:3]  [1]  [1]
# 98909   [1]  [5]  [4]    [1:abc, 2:mm]  [3]  [2:2]  [1]  [1]
#
#                        A08        A09  ...    A13  A14  B01              B02  \
# 客戶                                     ...
# 261909           [1, 3, 5]     [2, 3]  ...    [1]  [4]  [3]  [1, 2, 3, 4, 5]
# 269963           [3, 4, 5]     [1, 3]  ...    [1]  [4]  [5]           [4, 5]
# 270057           [1, 4, 5]        [1]  ...    [1]  [4]  [5]  [1, 2, 3, 4, 5]
# 270507  [1, 2, 3, 4, 5, 6]  [1, 2, 3]  ...    [1]  [4]  [2]  [1, 2, 3, 4, 5]
# 98909            [3, 4, 5]  [1, 2, 3]  ...    [1]  [4]  [4]     [1, 3, 4, 5]
#
#                     B03  B04  B05  B06  B07 QA風險等級
# 客戶
# 261909        [3, 4, 5]  [5]  [4]  [4]  [4]      5
# 269963           [4, 5]  [3]  [3]  [2]  [1]      5
# 270057  [1, 2, 3, 4, 5]  [3]  [3]  [2]  [2]      5
# 270507        [3, 4, 5]  [5]  [4]  [4]  [3]      5
# 98909         [1, 4, 5]  [3]  [3]  [3]  [3]      5
#
# [5 rows x 23 columns]

# %%
ans.to_excel('ans.xlsx')

# %%
invest = pd.read_excel("invest_data.xlsx")

# %%
invest.head(20)
# Out:
#         客戶  基金                   基金簡稱 風險等級      金額
# 0   100066   1       野村優質基金-累積類型新臺幣計價  RR4    3000
# 1   100066   5               野村 e科技基金  RR5   36079
# 2   100066   7            野村中小基金-累積類型  RR5   40000
# 3   100066   9     野村全球高股息基金-累積型新臺幣計價  RR4    3000
# 4   100066  30             野村精選貨幣市場基金  RR1       0
# 5   100066  37             野村全球生技醫療基金  RR4    9617
# 6   100066  46          野村新興傘型之大俄羅斯基金  RR5   54273
# 7   100066  48               野村中國機會基金  RR5  119385
# 8   100066  49     野村全球美元投資級公司債基金-累積型  RR2    5000
# 9   100066  51           野村巴西證券投資信託基金  RR5   88041
# 10  100066  55          野村雙印傘型之印尼潛力基金  RR5       0
# 11  100066  56  野村亞太複合高收益債基金-累積型新臺幣計價  RR4    3000
# 12  100066  94       野村全球短期收益基金-新台幣計價  RR2  232037
# 13  100066  95   野村多元收益平衡基金-累積類型新臺幣計價  RR3    3000
# 14  100066  A9   野村亞太新興債券基金-累積類型新臺幣計價  RR3    5000
# 15  100542  20           野村環球基金-新臺幣計價  RR4    3000
# 16  100558   7            野村中小基金-累積類型  RR5    6000
# 17  100558  18               野村台灣運籌基金  RR4    3000
# 18  100558  37             野村全球生技醫療基金  RR4       0
# 19  100558  48               野村中國機會基金  RR5    3000

# %%
invest["weight"] = invest["風險等級"].apply(lambda x:int(x[-1]))
invest["weight_amount"] = invest["weight"]*invest["金額"]

# %%
invest["weight_amount"]
# Out:
# 0         12000
# 1        180395
# 2        200000
# 3         12000
# 4             0
# 5         38468
# 6        271365
# 7        596925
# 8         10000
# 9        440205
# 10            0
# 11        12000
# 12       464074
# 13         9000
# 14        15000
# 15        12000
# 16        30000
# 17        12000
# 18            0
# 19        15000
# 20        12000
# 21        12000
# 22        12000
# 23        15000
# 24        20000
# 25        24000
# 26        40000
# 27        12000
# 28        12000
# 29        30000
#          ...
# 5790          0
# 5791       4000
# 5792     300000
# 5793      30000
# 5794     600000
# 5795     750000
# 5796    1500000
# 5797    1080000
# 5798     812973
# 5799      12000
# 5800      15000
# 5801      15000
# 5802       8000
# 5803          0
# 5804          0
# 5805          0
# 5806      15000
# 5807      40000
# 5808      80000
# 5809     400000
# 5810      60000
# 5811    1551965
# 5812          0
# 5813      20000
# 5814      15000
# 5815      12000
# 5816      12000
# 5817      15000
# 5818     120000
# 5819      50000
# Name: weight_amount, Length: 5820, dtype: int64

# %%
customer = list(set(invest["客戶"]))
customer_count = invest.groupby('客戶',as_index=False, sort=False).count()
customer_total = invest.groupby('客戶',as_index=False, sort=False).sum()
customer_total.head()
# Out:
#        客戶      金額  weight  weight_amount
# 0  100066  601432      57        2261432
# 1  100542    3000       4          12000
# 2  100558   12000      18          57000
# 3  100606   12000      17          51000
# 4  100657    5000       4          20000

# %%
customer_count.head()
# Out:
#        客戶  基金  基金簡稱  風險等級  金額  weight  weight_amount
# 0  100066  15    15    15  15      15             15
# 1  100542   1     1     1   1       1              1
# 2  100558   4     4     4   4       4              4
# 3  100606   4     4     4   4       4              4
# 4  100657   1     1     1   1       1              1

# %%
customer_total["weight_level"] = customer_total["weight_amount"]/customer_total["金額"]

# %%
customer_total.head()
# Out:
#        客戶      金額  weight  weight_amount  weight_level
# 0  100066  601432      57        2261432      3.760079
# 1  100542    3000       4          12000      4.000000
# 2  100558   12000      18          57000      4.750000
# 3  100606   12000      17          51000      4.250000
# 4  100657    5000       4          20000      4.000000

# %%
customer_total.set_index('客戶')
# Out:
#              金額  weight  weight_amount  weight_level
# 客戶
# 100066   601432      57        2261432      3.760079
# 100542     3000       4          12000      4.000000
# 100558    12000      18          57000      4.750000
# 100606    12000      17          51000      4.250000
# 100657     5000       4          20000      4.000000
# 101140   239128      69         933384      3.903282
# 105582  1625745      37        5706480      3.510071
# 123855   605746      21        2522972      4.165066
# 101150   351535      41         599077      1.704175
# 101275    90000      33         430000      4.777778
# 101614     6000      10          30000      5.000000
# 101976    35000      22         150000      4.285714
# 102122    38000      30         168000      4.421053
# 102123     9000      14          42000      4.666667
# 103813    10000       3          30000      3.000000
# 104972     3000       5          15000      5.000000
# 105001     4000       5          20000      5.000000
# 105002    96000      46         383000      3.989583
# 105146   251000      37         783000      3.119522
# 105188   114672      26         565360      4.930236
# 105292    45000      14         140000      3.111111
# 105314     6000       9          27000      4.500000
# 105417    15000      22          66000      4.400000
# 105482    33000      37         153000      4.636364
# 105528    12000      20          60000      5.000000
# 148472    29003      26         140012      4.827501
# 174992    34327       7         105981      3.087395
# 187080   663918      41        1867418      2.812724
# 188357    39946      22         170534      4.269113
# 211951    26000      10          98000      3.769231
# ...         ...     ...            ...           ...
# 87674      7000       9          31000      4.428571
# 87828      5000       5          25000      5.000000
# 88905      6000       9          27000      4.500000
# 89133     35000      23         160000      4.571429
# 89366      9000      12          36000      4.000000
# 90651      8000       9          37000      4.625000
# 90899      8000      10          40000      5.000000
# 91288     15000      14          65000      4.333333
# 92810         0       4              0           NaN
# 93049      3000       5          15000      5.000000
# 93286         0       9              0           NaN
# 93911     67472      18         301888      4.474271
# 95024    218895      20         290895      1.328925
# 95059     10000       9          45000      4.500000
# 95270     35000      22         150000      4.285714
# 95302         0       8              0           NaN
# 95345      3000       9          15000      5.000000
# 95354      3000       5          15000      5.000000
# 95535         0       5              0           NaN
# 95646      5000       5          25000      5.000000
# 95809     11000      14          52000      4.727273
# 310845   500000       3        1500000      3.000000
# 96179      9000      14          42000      4.666667
# 96728     35000      30         143000      4.085714
# 97399    120000       7         460000      3.833333
# 97620    310393      10        1551965      5.000000
# 98049      8000       9          35000      4.375000
# 98441      3000       4          12000      4.000000
# 98909      6000       9          27000      4.500000
# 99313     55000       6         170000      3.090909
#
# [1522 rows x 4 columns]

# %%
customer_df = customer_total[['客戶','weight_level']]
customer_df = customer_df.set_index('客戶')

# %%
customer_df.head()
# Out:
#         weight_level
# 客戶
# 100066      3.760079
# 100542      4.000000
# 100558      4.750000
# 100606      4.250000
# 100657      4.000000

# %%
customer_df = pd.merge(customer_df, ans,on='客戶')

# %%
customer_df.head()
# Out:
#         weight_level   A0   A01     A02              A03  A04    A05  A06  \
# 客戶
# 100066      3.760079  [1]  [22]  [7:無 ]   [1:待業中, 2:待業中]  [4]    [3]  [1]
# 100542      4.000000  [1]   [4]     [4]    [1:肯微, 2:財務部]  [4]  [1:0]  [1]
# 100558      4.750000  [1]   [8]  [7:退休]     [1:退休, 2:退休]  [4]    [3]  [1]
# 100606      4.250000  [1]   [4]     [5]  [1:祐盟電子, 2:管理部]  [3]  [2:2]  [1]
# 100657      4.000000  [1]   [1]     [4]    [1:市府, 2:環保局]  [5]  [1:1]  [1]
#
#         A07        A08  ...    A13  A14  B01              B02        B03  B04  \
# 客戶                      ...
# 100066  [1]  [1, 3, 5]  ...    [1]  [4]  [4]  [1, 2, 3, 4, 5]  [3, 4, 5]  [5]
# 100542  [1]     [1, 5]  ...    [1]  [4]  [5]     [1, 3, 4, 5]        [3]  [5]
# 100558  [1]        [1]  ...    [2]  [4]  [3]           [1, 4]     [2, 4]  [5]
# 100606  [1]  [1, 3, 5]  ...    [1]  [4]  [4]     [1, 3, 4, 5]     [4, 5]  [3]
# 100657  [1]        [1]  ...    [1]  [4]  [4]              [1]        [1]  [2]
#
#         B05  B06  B07 QA風險等級
# 客戶
# 100066  [4]  [5]  [5]      5
# 100542  [3]  [3]  [3]      5
# 100558  [3]  [3]  [4]      5
# 100606  [4]  [3]  [2]      5
# 100657  [3]  [2]  [1]      4
#
# [5 rows x 24 columns]

# %%
plt.hist(customer_df['weight_level'],bins=50)
# Out:
# C:\Users\Nick\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\Nick\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# (array([  3.,   1.,   3.,   2.,   3.,   1.,   1.,   0.,   1.,   6.,   1.,
#           3.,   6.,   2.,   5.,   4.,   1.,   0.,   3.,   0.,   0.,   0.,
#           2.,   2.,   3.,  45.,  17.,  21.,   7.,  14.,   8.,  16.,  14.,
#          11.,  14.,   7.,  11., 372.,  24.,  22.,  47.,  63.,  47., 127.,
#          35.,  72.,  40.,  51.,  32., 292.]),
#  array([1.  , 1.08, 1.16, 1.24, 1.32, 1.4 , 1.48, 1.56, 1.64, 1.72, 1.8 ,
#         1.88, 1.96, 2.04, 2.12, 2.2 , 2.28, 2.36, 2.44, 2.52, 2.6 , 2.68,
#         2.76, 2.84, 2.92, 3.  , 3.08, 3.16, 3.24, 3.32, 3.4 , 3.48, 3.56,
#         3.64, 3.72, 3.8 , 3.88, 3.96, 4.04, 4.12, 4.2 , 4.28, 4.36, 4.44,
#         4.52, 4.6 , 4.68, 4.76, 4.84, 4.92, 5.  ]),
#  <a list of 50 Patch objects>)

# %%
plt.hist(customer_df['weight_level'])
# Out:
# (array([ 12.,   9.,  17.,   8.,   7., 105.,  62., 436., 319., 487.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <a list of 10 Patch objects>)

# %%
customer_df[['QA風險等級']] = customer_df[['QA風險等級']].apply(pd.to_numeric)

# %%
plt.hist(customer_df['QA風險等級'])
# Out:
# (array([1.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00, 0.00e+00,
#         8.10e+01, 0.00e+00, 0.00e+00, 1.44e+03]),
#  array([2. , 2.3, 2.6, 2.9, 3.2, 3.5, 3.8, 4.1, 4.4, 4.7, 5. ]),
#  <a list of 10 Patch objects>)

# %%
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1522 entries, 100066 to 99313
# Data columns (total 24 columns):
# weight_level    1462 non-null float64
# A0              1522 non-null object
# A01             1522 non-null object
# A02             1522 non-null object
# A03             1522 non-null object
# A04             1522 non-null object
# A05             1520 non-null object
# A06             1520 non-null object
# A07             1520 non-null object
# A08             1520 non-null object
# A09             1520 non-null object
# A10             1520 non-null object
# A11             1520 non-null object
# A12             1520 non-null object
# A13             1520 non-null object
# A14             1520 non-null object
# B01             1520 non-null object
# B02             1520 non-null object
# B03             1520 non-null object
# B04             1520 non-null object
# B05             1520 non-null object
# B06             1520 non-null object
# B07             1520 non-null object
# QA風險等級          1522 non-null int64
# dtypes: float64(1), int64(1), object(22)
# memory usage: 297.3+ KB

# %% [markdown]
# # A0 X

# %%
A0_counter = Counter([qans for item in customer_df['A0'] for qans in item])
A0_counter
# Out:
# Counter({1: 1520, '3:中華民國': 1, '3:新加坡': 1, '3:日本': 1})

# %%
A01_counter = Counter([qans for item in customer_df['A01'] for qans in item])
A01_counter.most_common()
# Out:
# [(4, 253),
#  (5, 218),
#  (1, 191),
#  (8, 171),
#  (21, 137),
#  (3, 136),
#  (2, 86),
#  (6, 76),
#  (7, 56),
#  (22, 22),
#  (14, 22),
#  (12, 20),
#  (17, 14),
#  (9, 10),
#  ('24:自由業', 7),
#  ('13:日本', 6),
#  ('13:美國', 6),
#  (18, 4),
#  (20, 4),
#  ('13:歐美', 3),
#  ('13:大陸', 2),
#  ('13:德國', 2),
#  ('24:傳播', 2),
#  ('13:歐洲', 2),
#  ('24:補教業', 2),
#  ('24:出版業', 2),
#  ('24:物流業', 2),
#  ('24:未成年人', 2),
#  ('24:家教', 2),
#  ('24:布商生管', 1),
#  ('13:亞洲', 1),
#  ('24:自家', 1),
#  ('23:力行派報', 1),
#  ('23:農業機械', 1),
#  ('24:特約導遊', 1),
#  ('24:傳播業', 1),
#  ('24:打工', 1),
#  ('24:國營事業', 1),
#  ('23:殯葬業', 1),
#  ('23:機車行', 1),
#  ('13:日韓', 1),
#  ('24:國營企業', 1),
#  ('24:科學研究', 1),
#  ('13:捷克', 1),
#  ('23:冠林電器行', 1),
#  ('24:義務役兵役服役中', 1),
#  ('13:奈及利亞', 1),
#  ('24:自聘', 1),
#  ('13:中國大陸', 1),
#  ('13:印尼', 1),
#  ('23:無', 1),
#  (10, 1),
#  ('23:電池專賣店', 1),
#  ('13:germany', 1),
#  ('23:翻譯人員', 1),
#  ('24:派遣人力-派駐機關', 1),
#  ('24:電子/光學', 1),
#  ('23:正煌燈飾', 1),
#  ('13:英美', 1),
#  ('24:攤商', 1),
#  ('24:家管', 1),
#  ('13:歐美澳', 1),
#  ('24:出版', 1),
#  ('24:電子代理業', 1),
#  ('24:服務業', 1),
#  ('24:外包人員', 1),
#  ('24:退休', 1),
#  ('23:亞碩電腦科技', 1),
#  ('23:服飾商', 1),
#  ('24:補教', 1),
#  ('13:丹麥', 1),
#  ('24:零售業', 1),
#  ('13:印度', 1),
#  ('24:表演藝術', 1),
#  ('13:南非', 1),
#  ('24:美容', 1),
#  ('24:補習班', 1),
#  ('24:航空', 1),
#  ('23:三銘行', 1),
#  ('23:補教業', 1),
#  ('23:克林姆創意坊', 1),
#  ('24:基金會', 1),
#  ('13:日本、大陸', 1),
#  ('24:運輸業', 1),
#  ('24:藥品監管', 1),
#  (19, 1),
#  ('24:航運業', 1),
#  ('24:自由研究者(接案、寫作)', 1),
#  ('24:電影', 1),
#  ('24:生技', 1),
#  ('24:媒體業', 1),
#  ('24:運輸公司', 1),
#  ('24:媒體傳播', 1),
#  ('24:研究人員', 1),
#  ('23:農產品', 1),
#  ('24:配管材料買賣業', 1),
#  ('24:音樂老師', 1),
#  ('24:軍退', 1),
#  ('24:商業團體', 1),
#  ('13:korea', 1)]

# %%
A02_counter = Counter([qans for item in customer_df['A02'] for qans in item])
A02_counter.most_common()
# Out:
# [(1, 442),
#  (2, 311),
#  (4, 228),
#  (3, 124),
#  (5, 85),
#  ('7:家管', 84),
#  (6, 60),
#  ('7:無', 50),
#  ('7:退休', 36),
#  ('7:學生', 34),
#  ('7:退休人士', 11),
#  ('7:退休人員', 6),
#  ('7:已退休', 3),
#  ('7:助理', 3),
#  ('7:待業中', 3),
#  ('7:學齡前', 3),
#  ('7:家庭主婦', 2),
#  ('7:自營', 2),
#  ('7:未成年人', 2),
#  ('7:無 ', 1),
#  ('7:0', 1),
#  ('7:na', 1),
#  ('7:導遊', 1),
#  ('7:特約導遊', 1),
#  ('7:無職', 1),
#  ('7:無業', 1),
#  ('7:財會', 1),
#  ('7:勞工', 1),
#  ('7:業務', 1),
#  ('7:約聘助理', 1),
#  ('7:夫家事業', 1),
#  ('7:義務役兵役服役中', 1),
#  ('7:退休老師', 1),
#  ('7:家務負責人', 1),
#  ('7:退休無職', 1),
#  ('7:自聘', 1),
#  ('7:家長以子女名義購置', 1),
#  ('7:家園管理', 1),
#  ('7:休閒農業', 1),
#  ('7:Student', 1),
#  ('7:店員', 1),
#  ('7:家長購置子女名義基金', 1),
#  ('7:自由業', 1),
#  ('7:退休教師', 1),
#  ('7:teacher', 1),
#  ('7:外包人員', 1),
#  ('7:研究生', 1),
#  ('7:館長', 1),
#  ('7:合伙人', 1),
#  ('7:none', 1),
#  ('7:雄聲', 1),
#  ('7: 學生', 1),
#  ('7:自由研究者(接案、寫作)', 1),
#  ('7:碩2生', 1),
#  ('7:職員', 1),
#  ('7:兼職', 1),
#  ('7:家教音樂老師', 1),
#  ('7:待業', 1),
#  ('7:教師', 1),
#  ('7:軍退', 1),
#  ('7:倉管', 1),
#  ('7:家教老師', 1),
#  ('7:日文老師', 1)]

# %%
A031 = [qans for item in customer_df['A03'] for qans in item]
A031_counter = Counter([x for x in A03 if type(x)==str and x[0]=='1'])

# %%
A03_counter.most_common()
# Out:
# [('1:無', 143),
#  ('1:家管', 43),
#  ('1:野村投信', 23),
#  ('1:退休', 19),
#  ('1:學生', 11),
#  ('1:學校', 10),
#  ('1:自家', 9),
#  ('1:家', 8),
#  ('1:台電', 7),
#  ('1:中華郵政', 7),
#  ('1:自營', 7),
#  ('1:待業中', 6),
#  ('1:彰化銀行', 6),
#  ('1:退休人士', 5),
#  ('1:家裡', 5),
#  ('1:0', 5),
#  ('1:中華電信', 5),
#  ('1:已退休', 5),
#  ('1:醫院', 4),
#  ('1:公務機關', 4),
#  ('1:科技公司', 4),
#  ('1:貿易公司', 4),
#  ('1:自由業', 4),
#  ('1:國小', 4),
#  ('1:自宅', 4),
#  ('1:野村證券投資信託股份有限公司', 3),
#  ('1:基金會', 3),
#  ('1:長庚醫院', 3),
#  ('1:台灣大學', 3),
#  ('1:no', 3),
#  ('1:學齡前', 3),
#  ('1:投信投顧公會', 2),
#  ('1:台大', 2),
#  ('1:MTK', 2),
#  ('1:廣達電腦', 2),
#  ('1:元大銀行', 2),
#  ('1:公家機關', 2),
#  ('1:富邦', 2),
#  ('1:私人企業', 2),
#  ('1:台積電', 2),
#  ('1:11', 2),
#  ('1:公', 2),
#  ('1:家庭', 2),
#  ('1:中興大學', 2),
#  ('1:台灣中油股份有限公司', 2),
#  ('1:衛福部', 2),
#  ('1:聯合報', 2),
#  ('1:0000', 2),
#  ('1:國防部', 2),
#  ('1:板信商銀', 2),
#  ('1:富邦人壽', 2),
#  ('1:全豐利實業有限公司', 2),
#  ('1:國民小學', 2),
#  ('1:診所', 2),
#  ('1:屏山國小', 2),
#  ('1:家中', 2),
#  ('1:補習班', 2),
#  ('1:桃園醫院', 2),
#  ('1:友達光電', 2),
#  ('1:私人公司', 2),
#  ('1:國泰世華銀行', 2),
#  ('1:勞保局', 2),
#  ('1:東華大學', 2),
#  ('1:自營商', 2),
#  ('1:台灣世曦工程顧問股份有限公司', 2),
#  ('1:第一銀行', 2),
#  ('1:市政府', 2),
#  ('1:中央研究院', 2),
#  ('1:none', 2),
#  ('1:元大證券', 2),
#  ('1:公司', 2),
#  ('1:東海大學', 2),
#  ('1:三銘行', 2),
#  ('1:長星診所', 2),
#  ('1:國泰人壽', 2),
#  ('1:中山大學', 2),
#  ('1:衛生福利部金門醫院', 2),
#  ('1:台鐵', 2),
#  ('1:南山人壽', 2),
#  ('1:肯微', 1),
#  ('1:祐盟電子', 1),
#  ('1:市府', 1),
#  ('1:麗貿實業有限公司', 1),
#  ('1:僑委會', 1),
#  ('1:東電股份有限公ㄙ', 1),
#  ('1:宣誠聯合會計師事務所', 1),
#  ('1:FREELANCER', 1),
#  ('1:開發', 1),
#  ('1:堤維西交通工業股份有限公司', 1),
#  ('1:DBS', 1),
#  ('1:東明', 1),
#  ('1:國際票券', 1),
#  ('1:陸軍司令部', 1),
#  ('1:永豐銀行', 1),
#  ('1:自家／設計', 1),
#  ('1:敏盛醫院', 1),
#  ('1:經緯航太', 1),
#  ('1:醫全實業<股>公司', 1),
#  ('1:實福有限公司', 1),
#  ('1:振永貿易', 1),
#  ('1:美商安華高', 1),
#  ('1:松盛工業', 1),
#  ('1:統一企業股份有限公司', 1),
#  ('1:中山科學研究院', 1),
#  ('1:亞泰光學', 1),
#  ('1:啟源木業', 1),
#  ('1:堅若國際工業有限公司', 1),
#  ('1:na', 1),
#  ('1:久津', 1),
#  ('1:合作金庫', 1),
#  ('1:金融', 1),
#  ('1:SHENG-EN', 1),
#  ('1:某保險公司', 1),
#  ('1:OBI', 1),
#  ('1:台揚科技', 1),
#  ('1:secret', 1),
#  ('1:台灣樁本', 1),
#  ('1:台濼控制工桯 ', 1),
#  ('1:cycu', 1),
#  ('1:退休人士 ', 1),
#  ('1:國中', 1),
#  ('1:台中女中', 1),
#  ('1:旭晟印鐵製罐股份有限公司', 1),
#  ('1:進出口公司', 1),
#  ('1:源美建設股份有限公司', 1),
#  ('1:力行派報公司', 1),
#  ('1:CHT Lab.', 1),
#  ('1:救國團', 1),
#  ('1:CHINA Airlines', 1),
#  ('1:同步輻射研究中心', 1),
#  ('1:Quantum Touch', 1),
#  ('1:品質學會', 1),
#  ('1:史提芬診所', 1),
#  ('1:霸菱投顧', 1),
#  ('1:DuPont Taiwan/IT', 1),
#  ('1:保留', 1),
#  ('1:勞動部勞工保險局', 1),
#  ('1:台灣電力公司', 1),
#  ('1:警察', 1),
#  ('1:經登', 1),
#  ('1:駐英國代表處', 1),
#  ('1:夏指', 1),
#  ('1:國立體育大學', 1),
#  ('1:估勝保險經紀人股份有限公司', 1),
#  ('1:玉里高中', 1),
#  ('1:裕信股份有限公司', 1),
#  ('1: 詹求孚診所', 1),
#  ('1:旅行社', 1),
#  ('1:桃園市立陽明高中', 1),
#  ('1:麥肯積體電路(股)公司', 1),
#  ('1:保生診所', 1),
#  ('1:艾德蒙海外股份有限公司', 1),
#  ('1:桃園市菓林國小', 1),
#  ('1:震雄機械廠股份有限公司', 1),
#  ('1:總達鑫公司', 1),
#  ('1:車亭企業股份有限公司', 1),
#  ('1:長榮航宇', 1),
#  ('1:taiwan', 1),
#  ('1:周賢章耳鼻喉科診所', 1),
#  ('1:拒答', 1),
#  ('1:國ˋ中', 1),
#  ('1:鋒裕匯理投顧', 1),
#  ('1:德宏', 1),
#  ('1:協辰電信', 1),
#  ('1:政府單位', 1),
#  ('1:華盛頓中學', 1),
#  ('1:大器公司', 1),
#  ('1:恩德科技', 1),
#  ('1:東陽實業', 1),
#  ('1:英業達股份有限公司', 1),
#  ('1:無 ', 1),
#  ('1:出版社', 1),
#  ('1:美商公司', 1),
#  ('1:善元科技', 1),
#  ('1:王政企業社', 1),
#  ('1:靜宜大學', 1),
#  ('1:長航', 1),
#  ('1:財金資訊股份有限公司', 1),
#  ('1:善德生化科技', 1),
#  ('1:通霄發電廠', 1),
#  ('1:太昊航空', 1),
#  ('1:新北市三重區公所', 1),
#  ('1:金瑞瑩', 1),
#  ('1:123', 1),
#  ('1:特約導遊', 1),
#  ('1:台北榮總', 1),
#  ('1:無職', 1),
#  ('1:雅墨文化', 1),
#  ('1:新唐科技', 1),
#  ('1:彰化縣立溪州國中', 1),
#  ('1:旺旺中時媒體集團', 1),
#  ('1:台糖', 1),
#  ('1:臺銀人壽', 1),
#  ('1:中盛科技', 1),
#  ('1:臺北市政府勞動局', 1),
#  ('1:資訊公司', 1),
#  ('1:門諾醫院', 1),
#  ('1:電信公司', 1),
#  ('1:東門國小', 1),
#  ('1:大立光電股份有限公司', 1),
#  ('1:傑暄會計記帳士事務所', 1),
#  ('1:信昌中醫診所', 1),
#  ('1:國小老師', 1),
#  ('1:屏東縣振興國小', 1),
#  ('1:潤泰全球股份有限公司', 1),
#  ('1:鞋業', 1),
#  ('1:金船', 1),
#  ('1:佛洛里恩行動咖啡', 1),
#  ('1:聲寶', 1),
#  ('1:台中市政府', 1),
#  ('1: 虎克資訊工作室', 1),
#  ('1:忠杏股份有限公司', 1),
#  ('1:飼料行', 1),
#  ('1:幾維科技有限公司', 1),
#  ('1:華美光學科技', 1),
#  ('1:楊民五金', 1),
#  ('1:全民動物醫院', 1),
#  ('1:福盈科技化學', 1),
#  ('1:合益禮儀社', 1),
#  ('1:家榮公司', 1),
#  ('1:大方牙醫', 1),
#  ('1:基隆市政府', 1),
#  ('1:Inno-Tech', 1),
#  ('1:中华汽车', 1),
#  ('1:仁寶', 1),
#  ('1:黎明興', 1),
#  ('1:台鐵局', 1),
#  ('1:必榮機車', 1),
#  ('1:橅', 1),
#  ('1:勤基工程', 1),
#  ('1:民視', 1),
#  ('1:墾青工業公司', 1),
#  ('1:長松綠診所', 1),
#  ('1:永利', 1),
#  ('1:暐立實業有限公司', 1),
#  ('1:丹鳳高中', 1),
#  ('1:裕強生技股份有限公司', 1),
#  ('1:致盈有限公司', 1),
#  ('1:台壽保產險', 1),
#  ('1:三商美邦', 1),
#  ('1:合騏工業', 1),
#  ('1:美琦企業有限公司', 1),
#  ('1:亞邦國際科技', 1),
#  ('1:財政部台中關', 1),
#  ('1:金字塔公司', 1),
#  ('1:台灣住友商事股份有限公司', 1),
#  ('1:漢聮海運', 1),
#  ('1:和泰產險', 1),
#  ('1:和昭實業股份有限公司', 1),
#  ('1:金慶威股', 1),
#  ('1:巨寶軒', 1),
#  ('1:慶揚國際有限公司', 1),
#  ('1:亞洲蔬菜中心', 1),
#  ('1:永業興土木包工業', 1),
#  ('1:彰化基督教醫院', 1),
#  ('1:錠嵂保險經紀人', 1),
#  ('1:新竹市立內湖國中', 1),
#  ('1:南山人壽保險股份有限公司', 1),
#  ('1:每新工業', 1),
#  ('1:京元電子', 1),
#  ('1:瀚軒股份有限公司', 1),
#  ('1:外交部', 1),
#  ('1:日月光', 1),
#  ('1:逸松股份有限公司', 1),
#  ('1:泰元鋼業', 1),
#  ('1:食藥署', 1),
#  ('1:路竹地政', 1),
#  ('1:聖育科技股份有限公司', 1),
#  ('1:博智電子', 1),
#  ('1:美商安邁科技台灣分公司', 1),
#  ('1:梧棲農會', 1),
#  ('1:偉暄辦公傢俱設計股份有限公司', 1),
#  ('1:中國國民黨中央委員會', 1),
#  ('1:臺北城市科技大學', 1),
#  ('1:俊泰', 1),
#  ('1:73376849', 1),
#  ('1:世新大學', 1),
#  ('1:聯亞藥業股份有限公司', 1),
#  ('1:國立臺北教育大學', 1),
#  ('1:台灣摩迪高', 1),
#  ('1:基隆市立八斗高級中學', 1),
#  ('1:準訊生醫', 1),
#  ('1:桃園建國國小', 1),
#  ('1:長榮海運', 1),
#  ('1:財團英檢公司', 1),
#  ('1:統一綜合證券股份有限公司', 1),
#  ('1:牙醫診所', 1),
#  ('1:衛生福利部桃園醫院', 1),
#  ('1:泉新冷氣行', 1),
#  ('1:國立岡山高中', 1),
#  ('1:九豪', 1),
#  ('1:台東縣新生國中', 1),
#  ('1:信大水泥', 1),
#  ('1:大成國中', 1),
#  ('1:國泰世紀產險', 1),
#  ('1:通運公司', 1),
#  ('1:旭德科技', 1),
#  ('1:岡山木材行', 1),
#  ('1:第二題都說待業了還一定要填這欄，莫名其妙', 1),
#  ('1:顧診所', 1),
#  ('1:荷蘭貿易暨投資辦事處', 1),
#  ('1:台北法院', 1),
#  ('1:威策', 1),
#  ('1:揚捷有限公司', 1),
#  ('1:四零四科技股份有限公司', 1),
#  ('1:一飛國際有限公司', 1),
#  ('1:行政', 1),
#  ('1:全國農業金庫', 1),
#  ('1:基隆市仁愛國小', 1),
#  ('1:信和國際法律事務所', 1),
#  ('1:冠林電器行', 1),
#  ('1:貝爾驗證機構', 1),
#  ('1:建泓報關', 1),
#  ('1:友达光电', 1),
#  ('1:方濟中學', 1),
#  ('1:一般公司', 1),
#  ('1:私立幼心幼兒園', 1),
#  ('1:信保基金', 1),
#  ('1:健保署', 1),
#  ('1:桃園市公所', 1),
#  ('1:光陽工業股份有限公司', 1),
#  ('1:捷特多媒體數位股份有限公司', 1),
#  ('1:南港高工', 1),
#  ('1:輔仁大學', 1),
#  ('1:如陽公司', 1),
#  ('1:home', 1),
#  ('1:火鍋店', 1),
#  ('1:中天電視', 1),
#  ('1:新莊國中', 1),
#  ('1:恒美窗簾製作', 1),
#  ('1:LBOT', 1),
#  ('1:AUO', 1),
#  ('1:中華郵政股份有限公司', 1),
#  ('1:明德國小', 1),
#  ('1:中華民國', 1),
#  ('1:福齡牙科診所', 1),
#  ('1:芳全有限公司', 1),
#  ('1:日商野村貿易', 1),
#  ('1:NETGEAR', 1),
#  ('1:新竹市立建功高中', 1),
#  ('1:中華電', 1),
#  ('1:永裕', 1),
#  ('1:在家理財', 1),
#  ('1:六安堂國藥號', 1),
#  ('1:南台科技大學', 1),
#  ('1:巧奇佳', 1),
#  ('1:巧奇佳企業', 1),
#  ('1:燿華電子', 1),
#  ('1:kyec', 1),
#  ('1:運輸', 1),
#  ('1:民間', 1),
#  ('1:敦力', 1),
#  ('1:保吉生', 1),
#  ('1:港捷國際運通有限公司', 1),
#  ('1:浩銘牙科', 1),
#  ('1:健合營造股份有限公司', 1),
#  ('1:元隆電子', 1),
#  ('1:詮鼎電子', 1),
#  ('1:景碩', 1),
#  ('1:自聘', 1),
#  ('1:金管會', 1),
#  ('1:恒大股份有限公司', 1),
#  ('1:明星照明有限公司', 1),
#  ('1:宏浚國際股份有限公司', 1),
#  ('1:潤弘', 1),
#  ('1:連盛會計師事務所', 1),
#  ('1:翌宏股份有限公司', 1),
#  ('1:慈航國樂', 1),
#  ('1:NCHC', 1),
#  ('1:依睿瑪國際有限公司', 1),
#  ('1:元崗企業有限公司', 1),
#  ('1:太欣企業', 1),
#  ('1:經濟部', 1),
#  ('1:網動科技', 1),
#  ('1:關西塗料', 1),
#  ('1:中華電信台北營運處', 1),
#  ('1:朝陽科技大學', 1),
#  ('1:家樂福', 1),
#  ('1:富元汽車材料有限公司', 1),
#  ('1:奇鎂設計興業股份有限公司', 1),
#  ('1:九鼎豆花店', 1),
#  ('1:三鈴消防有現公司', 1),
#  ('1:環保局', 1),
#  ('1:環鴻科技股份有限公司 ', 1),
#  ('1:新北稅處', 1),
#  ('1:明基三豐醫療器材股份有限公司', 1),
#  ('1:聯宏資通股份有限公司', 1),
#  ('1:儒將貿易有限公司', 1),
#  ('1:全家旅行社', 1),
#  ('1:圓山飯店', 1),
#  ('1:建達國際', 1),
#  ('1:華三營造公司', 1),
#  ('1:國軍高雄總醫院', 1),
#  ('1:台灣鑽石工業股份有限公司', 1),
#  ('1:秀傳醫院', 1),
#  ('1:敬鵬工業', 1),
#  ('1:韋泰有限公司', 1),
#  ('1:個人工作室', 1),
#  ('1:名間鄉公所', 1),
#  ('1:研究機構', 1),
#  ('1:東和鋼鐵', 1),
#  ('1:亞利預鑄工業股份有限公司', 1),
#  ('1:高鼎', 1),
#  ('1:中英記帳事務所', 1),
#  ('1:歌林', 1),
#  ('1:蕃茄村漢堡', 1),
#  ('1:張大川聯合診所', 1),
#  ('1:進達工業股份有限公司', 1),
#  ('1:中國廣播', 1),
#  ('1:台灣歐地希股份有限公司', 1),
#  ('1:投資業', 1),
#  ('1:立益育樂股份有限公司', 1),
#  ('1:雜誌社', 1),
#  ('1:瑞芳高工', 1),
#  ('1:公部門', 1),
#  ('1:福隆玻璃纖維股份有限公司', 1),
#  ('1:賽仕電腦', 1),
#  ('1:電子公司', 1),
#  ('1:致正國際法律事務所', 1),
#  ('1:台達電子', 1),
#  ('1:ETC', 1),
#  ('1:清華大學', 1),
#  ('1:NFA', 1),
#  ('1:晶天動地水晶坊', 1),
#  ('1:國立台南藝術大學', 1),
#  ('1:野村', 1),
#  ('1:育達高中', 1),
#  ('1:台灣矽力杰', 1),
#  ('1:工程顧問', 1),
#  ('1:中心', 1),
#  ('1:VGHTC', 1),
#  ('1:佳和診所', 1),
#  ('1:重德耳鼻喉科', 1),
#  ('1:APEX INTERNATIONAL', 1),
#  ('1:台灣柏恩氏電子', 1),
#  ('1:聯合專利商標事務所', 1),
#  ('1:音律', 1),
#  ('1:台灣三菱電梯股份有限公司', 1),
#  ('1:內政部', 1),
#  ('1:久尹股份有限公司', 1),
#  ('1:AAA', 1),
#  ('1:合作金庫商業銀行', 1),
#  ('1:台灣樂金生活健康股份有限公司', 1),
#  ('1: 製造', 1),
#  ('1:利百景', 1),
#  ('1:花蓮二信', 1),
#  ('1:大明記帳事務所', 1),
#  ('1:財團法人台東縣私立牧心智能發展中心', 1),
#  ('1:國立臺灣史前文化博物館', 1),
#  ('1:富邦證券', 1),
#  ('1:NCCU', 1),
#  ('1:互動國際數位', 1),
#  ('1:瑞峰半導體股份有限公司', 1),
#  ('1:東宜資訊', 1),
#  ('1:立維行', 1),
#  ('1:陳氏', 1),
#  ('1:林口長庚紀念醫院', 1),
#  ('1:台灣微軟', 1),
#  ('1:會計師事務所', 1),
#  ('1:立耀電子股份有限公司', 1),
#  ('1:美和科技大學', 1),
#  ('1:研發', 1),
#  ('1:東亞公司', 1),
#  ('1:swatch group', 1),
#  ('1:達人女中', 1),
#  ('1:FET', 1),
#  ('1:台灣標準顧問有限公司', 1),
#  ('1:富藝科技有限公司', 1),
#  ('1:星展', 1),
#  ('1:海達科技社', 1),
#  ('1:和碩', 1),
#  ('1:中小企業總會', 1),
#  ('1:正煌燈飾', 1),
#  ('1:震江系統股份有限公司', 1),
#  ('1:民間企業', 1),
#  ('1:台灣大福', 1),
#  ('1:迦元實業有限公司', 1),
#  ('1:超捷', 1),
#  ('1:寵物店', 1),
#  ('1:寶豐', 1),
#  ('1:宏達國際', 1),
#  ('1:曲辰實業有限公司', 1),
#  ('1:天華企業股份有限公司', 1),
#  ('1:渣打', 1),
#  ('1:nil', 1),
#  ('1:登富企業有限公司', 1),
#  ('1:國立東港海事學校', 1),
#  ('1:線藝電子股份有限公司', 1),
#  ('1:果菜市場', 1),
#  ('1:台北富邦銀行', 1),
#  ('1:桂冠實業股份有限公司', 1),
#  ('1:tsmc', 1),
#  ('1:三福 ', 1),
#  ('1:同安國小', 1),
#  ('1:旭剛', 1),
#  ('1:家庭主婦', 1),
#  ('1:裕利股份有限公司', 1),
#  ('1:MSI', 1),
#  ('1:Siemens ', 1),
#  ('1:王邦企業有限公司', 1),
#  ('1:育嬰假', 1),
#  ('1:奇磊股份有限公司', 1),
#  ('1:翰林出版社', 1),
#  ('1:速比科技(股)', 1),
#  ('1:東三積體電子股份有限公司', 1),
#  ('1:創意電子', 1),
#  ('1:旭然', 1),
#  ('1:其泰股份有限公司', 1),
#  ('1:台灣科技大學', 1),
#  ('1:新加坡商鈦坦科技', 1),
#  ('1:LIBRA', 1),
#  ('1:退休人員', 1),
#  ('1:亞洲遊', 1),
#  ('1:玉山國小', 1),
#  ('1:霧峰區霧峰國小', 1),
#  ('1:北門農工', 1),
#  ('1:蓬萊中原實業有限公司', 1),
#  ('1:吉華商店', 1),
#  ('1:大甲國中', 1),
#  ('1:春田公司', 1),
#  ('1:永鎰實業', 1),
#  ('1:野村投信公司', 1),
#  ('1:長頸鹿美語', 1),
#  ('1:臺灣聯合法律事務所', 1),
#  ('1:瑋柱有限公司', 1),
#  ('1:信安郵通', 1),
#  ('1:台北市政府工務局新建工程處', 1),
#  ('1:君悅飯店', 1),
#  ('1:杏城藥局', 1),
#  ('1:行得利', 1),
#  ('1:tsti', 1),
#  ('1:台新', 1),
#  ('1:馬偕紀念醫院', 1),
#  ('1:新北市麗園國小', 1),
#  ('1:國軍', 1),
#  ('1:杜風工程顧問公司', 1),
#  ('1:艾特爾', 1),
#  ('1:法務部矯正署桃園監獄', 1),
#  ('1:第一金投信', 1),
#  ('1:茗得', 1),
#  ('1:Quanta', 1),
#  ('1:中央產物保險公司', 1),
#  ('1:荷蘭商漢微科股份有限公司南科分公司', 1),
#  ('1:員帥企業', 1),
#  ('1:致康診所', 1),
#  ('1:  竹林國小附設幼兒園', 1),
#  ('1:n', 1),
#  ('1:聖約翰科大', 1),
#  ('1:college', 1),
#  ('1:台電輸工處', 1),
#  ('1:白金科技股份有限公司', 1),
#  ('1:加高電子股份有限公司', 1),
#  ('1:伸保', 1),
#  ('1:祐民醫院', 1),
#  ('1:Chicony', 1),
#  ('1:士林電機', 1),
#  ('1:九和洋傘股份有限公司', 1),
#  ('1:龍井國小', 1),
#  ('1:台灣寶安康高爾夫管理顧問公司', 1),
#  ('1:均豪精密工業股份有限公司', 1),
#  ('1:中山大學研究所', 1),
#  ('1:保吉企業股份有限公司', 1),
#  ('1:居家', 1),
#  ('1:凱鈺科技股份有限公司', 1),
#  ('1:永吉國中', 1),
#  ('1:環隆科技', 1),
#  ('1:Nomura Asset Management Taiwan', 1),
#  ('1:新竹市監理站', 1),
#  ('1:南亞塑膠公司', 1),
#  ('1:政治大學', 1),
#  ('1:秉伸興業股份有限公司', 1),
#  ('1:大陸型氣候', 1),
#  ('1:1107測試', 1),
#  ('1:科德寶遠東(股)', 1),
#  ('1:亞洲大學', 1),
#  ('1:升揚消防', 1),
#  ('1:陽信銀行', 1),
#  ('1:Nomura', 1),
#  ('1:TWNIC', 1),
#  ('1:亞碩電腦科技', 1),
#  ('1:新苑開發股份有限公司', 1),
#  ('1:員山國中', 1),
#  ('1:大緯服裝行', 1),
#  ('1:國防大學理工學院', 1),
#  ('1:CHT', 1),
#  ('1:高醫附設醫院', 1),
#  ('1:超逾', 1),
#  ('1:文教機構', 1),
#  ('1:宜蘭大學', 1),
#  ('1:永育兒童城幼兒園', 1),
#  ('1:星星工作室', 1),
#  ('1:福豐自動化股份有限公司', 1),
#  ('1:永全益公司', 1),
#  ('1:安本', 1),
#  ('1:星裕國際股份有限公司', 1),
#  ('1:三商家購', 1),
#  ('1:亞洲水泥股份有限公司', 1),
#  ('1:舞匠國際藝術訪', 1),
#  ('1:環球倉儲股份有限公司', 1),
#  ('1:恆旺實業有限公司', 1),
#  ('1:Home', 1),
#  ('1:金允成', 1),
#  ('1:恆豐股份有限公司', 1),
#  ('1:台北藝術大學', 1),
#  ('1:江翠國中', 1),
#  ('1:統智科技股份有限公司', 1),
#  ('1:信保', 1),
#  ('1:金門大學', 1),
#  ('1:台中林酒店', 1),
#  ('1:群創', 1),
#  ('1:彰化藝術高中', 1),
#  ('1:大學老師', 1),
#  ('1:金旭資訊股份有限公司', 1),
#  ('1:中衛科技股份有限公司', 1),
#  ('1:白煌銘診所', 1),
#  ('1:台灣日立', 1),
#  ('1:ASET', 1),
#  ('1:台灣湛新股份有限公司', 1),
#  ('1:矽平', 1),
#  ('1:中信證', 1),
#  ('1:食品', 1),
#  ('1:臺中國小', 1),
#  ('1:宏福實業', 1),
#  ('1:詠賛聯合診所', 1),
#  ('1:親親', 1),
#  ('1:土地銀行', 1),
#  ('1:巨金針織', 1),
#  ('1:台灣京東方', 1),
#  ('1:金控', 1),
#  ('1:花店', 1),
#  ('1:國賓飯店', 1),
#  ('1:世禾科技', 1),
#  ('1:財政部關務署', 1),
#  ('1:念德鋼鐵公司', 1),
#  ('1:Epcistream', 1),
#  ('1:台灣萊雅股份有限公司', 1),
#  ('1:東安開發', 1),
#  ('1:南門國小', 1),
#  ('1:諾貝兒寶貝(股)公司', 1),
#  ('1:金融保險', 1),
#  ('1:xx', 1),
#  ('1:士瑞克', 1),
#  ('1:戲曲學院', 1),
#  ('1:風格電腦排版影印中心', 1),
#  ('1:文化大學', 1),
#  ('1:亞星通股份有限公司', 1),
#  ('1:富邦金控', 1),
#  ('1:奇聖', 1),
#  ('1:威爾儀控', 1),
#  ('1:音樂教學中心', 1),
#  ('1:小赤佬', 1),
#  ('1:小赤荖', 1),
#  ('1:萬國法律事務所', 1),
#  ('1:仁光中醫診所', 1),
#  ('1:丞曜實業', 1),
#  ('1:證券', 1),
#  ('1:歐艾斯', 1),
#  ('1:實踐國中', 1),
#  ('1:1232', 1),
#  ('1:泰北高中', 1),
#  ('1:益鼎', 1),
#  ('1:大山事務機器有限公司', 1),
#  ('1:再興', 1),
#  ('1:台灣必成', 1),
#  ('1:鴻豐', 1),
#  ('1:飛鵬有限公司', 1),
#  ('1:新光人壽', 1),
#  ('1:廷帛企業有限公司', 1),
#  ('1:華國飯店', 1),
#  ('1:Yuanta SEC', 1),
#  ('1:弘誼企業有限公司', 1),
#  ('1:建中', 1),
#  ('1:鼎旺不動產', 1),
#  ('1:艾訊', 1),
#  ('1:允大鋁業股份有限公司', 1),
#  ('1:便利商店', 1),
#  ('1:資產管理', 1),
#  ('1:埕鋐營造', 1),
#  ('1:長榮航太公司', 1),
#  ('1:至傑', 1),
#  ('1:台北醫學大學', 1),
#  ('1:機關', 1),
#  ('1:國中 ', 1),
#  ('1:密', 1),
#  ('1:路加醫學科技', 1),
#  ('1:翔名科技股份有限公司', 1),
#  ('1:清潔醫生', 1),
#  ('1:穩懋半導體', 1),
#  ('1:彩虹愛家', 1),
#  ('1:東宏昌有限公司', 1),
#  ('1:中華國中', 1),
#  ('1:宜蘭高中', 1),
#  ('1:集志科技股份有限公司', 1),
#  ('1:cc', 1),
#  ('1:源豐', 1),
#  ('1:傳象科技', 1),
#  ('1:餐飲業', 1),
#  ('1:美麗華影城', 1),
#  ('1:台灣 偉 登', 1),
#  ('1:力成科技', 1),
#  ('1:金士頓', 1),
#  ('1:an tai', 1),
#  ('1:國立交通大學', 1),
#  ('1:空中美語文教事業股份有限公司', 1),
#  ('1:華南永昌證券', 1),
#  ('1:黃禎憲皮膚科診所', 1),
#  ('1:富邦媒體', 1),
#  ('1:張榮發基金會', 1),
#  ('1:勇昇資訊科技有限公司', 1),
#  ('1:閣林文創', 1),
#  ('1:安信國際資產', 1),
#  ('1:全富嘉貿易', 1),
#  ('1:康橋集團', 1),
#  ('1:Molex Taiwan', 1),
#  ('1:立發順企業有限公司', 1),
#  ('1:勝甲企業有限公司', 1),
#  ('1:朱老師家教班', 1),
#  ('1:菱生', 1),
#  ('1:利敦', 1),
#  ('1:裕展股份有限公司', 1),
#  ('1:桃園石門國小', 1),
#  ('1:不便告知', 1),
#  ('1:臺中市南區衛生所', 1),
#  ('1:台日古河銅箔股份有限公司', 1),
#  ('1:高山企業', 1),
#  ('1:車業', 1),
#  ('1:中強光電', 1),
#  ('1:大宇資訊', 1),
#  ('1:希捷科技', 1),
#  ('1:兆里法律事務所', 1),
#  ('1:b', 1),
#  ('1:自', 1),
#  ('1:外商', 1),
#  ('1:正洸股份有限公司', 1),
#  ('1:七星國際', 1),
#  ('1:freight investor services pte ltd', 1),
#  ('1:mavega asia', 1),
#  ('1:資誠會計師事務所', 1),
#  ('1:伯驊印刷', 1),
#  ('1:烘焙房', 1),
#  ('1:民航局', 1),
#  ('1:成功高中', 1),
#  ('1:民間機構', 1),
#  ('1:台南市崇明國小', 1),
#  ('1:大倫', 1),
#  ('1:嘉里大榮物流(股)公司', 1),
#  ('1:板橋郵局', 1),
#  ('1:復興商工', 1),
#  ('1:住家', 1),
#  ('1:東南興', 1),
#  ('1:MKS Instruments', 1),
#  ('1:大陸委員會', 1),
#  ('1:凡允公司', 1),
#  ('1:臺中市立大華國中', 1),
#  ('1:中華航空公司修護工廠', 1),
#  ('1:翊榕公司', 1),
#  ('1:專美', 1),
#  ('1:鑫賀貨運', 1),
#  ('1:財團法人瑪利亞社會福利基金會', 1),
#  ('1:中科院', 1),
#  ('1:臺北市立聯合醫院忠孝院區', 1),
#  ('1:光電業', 1),
#  ('1:資誠會計師事務所 ', 1),
#  ('1:好樂事股份有限公司', 1),
#  ('1:Taipei veterans general hospital', 1),
#  ('1:國泰', 1),
#  ('1:台灣黑輪伯食品有限公司', 1),
#  ('1:000', 1),
#  ('1:富士達', 1),
#  ('1:j無', 1),
#  ('1:聯發科技', 1),
#  ('1:國立臺灣師範大學', 1),
#  ('1:爾太股份有限公司', 1),
#  ('1:承景科技', 1),
#  ('1:三安科技', 1),
#  ('1:高雄長庚醫院', 1),
#  ('1:某國中', 1),
#  ('1:你知我知股份有限公司', 1),
#  ('1:合發服飾有限公司', 1),
#  ('1:台灣大昌華嘉', 1),
#  ('1:幼兒園', 1),
#  ('1:非營利組織', 1),
#  ('1:北一女', 1),
#  ('1:昭惠', 1),
#  ('1:林記公司', 1),
#  ('1:全球人壽保險(股)', 1),
#  ('1:建國國中', 1),
#  ('1:國家同步輻射研究中心', 1),
#  ('1:青寶', 1),
#  ('1:東成 西就', 1),
#  ('1:八 達', 1),
#  ('1:玲玲美髮', 1),
#  ('1:中山國小', 1),
#  ('1:統一超商', 1),
#  ('1:第一金證券彰化分公司', 1),
#  ('1:鋼鐵公司', 1),
#  ('1:味帝企業股份有限公司', 1),
#  ('1:中山補習班', 1),
#  ('1:無公司', 1),
#  ('1:工研院', 1),
#  ('1:高雄市消防局', 1),
#  ('1:佑新興業有限公司秘書', 1),
#  ('1:荷商聯邦快遞股份有限公司', 1),
#  ('1:東瑞電子', 1),
#  ('1:趣淘漫旅', 1),
#  ('1:宏華國際有限公司', 1),
#  ('1:南台灣檢驗所', 1),
#  ('1:康麒電動車', 1),
#  ('1:自立國小', 1),
#  ('1:北區國稅局', 1),
#  ('1: 教師', 1),
#  ('1:立固', 1),
#  ('1:飛捷', 1),
#  ('1:竹東國小', 1),
#  ('1:東元綜合醫院', 1),
#  ('1:台灣水泥', 1),
#  ('1:健運企業', 1),
#  ('1:公營運輸', 1),
#  ('1:壢新', 1),
#  ('1:臺北大眾捷運股份有限公司', 1),
#  ('1:基富通證券股份有限公司', 1),
#  ('1:登山友商店有限公司', 1),
#  ('1:公務員', 1),
#  ('1:正上', 1),
#  ('1:智勤工業股份有限公司', 1),
#  ('1:嘉鋒五金', 1),
#  ('1:龍和診所', 1),
#  ('1:味丹企業', 1),
#  ('1:郵政公司', 1),
#  ('1:Nokia', 1),
#  ('1:楊貞芳眼科診所', 1),
#  ('1:csist', 1),
#  ('1:欣雄天然氣股份有限公司', 1),
#  ('1:文理補習班', 1),
#  ('1:克林姆創意坊', 1),
#  ('1:立志偉', 1),
#  ('1:家園', 1),
#  ('1:泰山中藥行', 1),
#  ('1:漢霖記帳士事務所', 1),
#  ('1:54JO6EJ/ N ', 1),
#  ('1:苗栗縣政府', 1),
#  ('1:高雄捷運公司', 1),
#  ('1:鍵鋐企業', 1),
#  ('1:中鋼運通', 1),
#  ('1:宏碁科技', 1),
#  ('1:江業', 1),
#  ('1:國防', 1),
#  ('1:光源公司', 1),
#  ('1:國新汽材', 1),
#  ('1:華業建師所', 1),
#  ('1:王道銀行', 1),
#  ('1:中國人壽', 1),
#  ('1:III', 1),
#  ('1:平曜代書', 1),
#  ('1:華國大飯店', 1),
#  ('1:佑民', 1),
#  ('1:飛訊資訊科技有限公司', 1),
#  ('1:貫新企業', 1),
#  ('1:公教團體', 1),
#  ('1:上和自動化有限公司', 1),
#  ('1:裕民航運公司', 1),
#  ('1:國眾電腦', 1),
#  ('1:玉山商業銀行', 1),
#  ('1:娉僱人員  ', 1),
#  ('1:中華電信公司', 1),
#  ('1:當代牙科', 1),
#  ('1:厚紀不銹鋼', 1),
#  ('1:強世智能科技', 1),
#  ('1:亞太飯店', 1),
#  ('1:臺大醫院', 1),
#  ('1:三商美邦人壽', 1),
#  ('1:毅懋企業有限公司', 1),
#  ('1:台灣人壽', 1),
#  ('1:高雄市政府', 1),
#  ('1:周大福股份公司', 1),
#  ('1:達方店子', 1),
#  ('1:都林工業', 1),
#  ('1:傑生資訊有限公司', 1),
#  ('1:台耀公司', 1),
#  ('1:統ㄧ企業', 1),
#  ('1:早餐店', 1),
#  ('1:海巡署', 1),
#  ('1:中華工程', 1),
#  ('1:再一實業有限公司', 1),
#  ('1:達爾文補習班', 1),
#  ('1:英科智能有限公司', 1),
#  ('1:泉能開發股份有限公司', 1),
#  ('1:國家安全會議', 1),
#  ('1:三民牙醫診所', 1),
#  ('1:輔大', 1),
#  ('1:奇欣美髮', 1),
#  ('1:Cal', 1),
#  ('1:元智', 1),
#  ('1:逢甲大學', 1),
#  ('1:玉井工商', 1),
#  ('1:東森', 1),
#  ('1:衛理女中', 1),
#  ('1:宏佳/主管', 1),
#  ('1:景美國中', 1),
#  ('1:大學', 1),
#  ('1:私人機構', 1),
#  ('1:萬岳', 1),
#  ('1:力承', 1),
#  ('1:compal', 1),
#  ('1:修德ˊ幼稚園', 1),
#  ('1:彰濱秀傳醫院', 1),
#  ('1:國藝會', 1),
#  ('1:艾達貿易有限公司', 1),
#  ('1:夏之雪', 1),
#  ('1:學生未任職', 1),
#  ('1:博群', 1),
#  ('1:中山醫院', 1),
#  ('1:Lam', 1),
#  ('1:長榮航空', 1),
#  ('1:欣傳媒', 1),
#  ('1:夏立雲診所', 1),
#  ('1:Center for Drug Evaluation', 1),
#  ('1:新社國小', 1),
#  ('1:金經成銀樓有限公司', 1),
#  ('1:寶緯', 1),
#  ('1:略', 1),
#  ('1:梧棲區農會', 1),
#  ('1:經濟部智慧財產局', 1),
#  ('1:新安東京', 1),
#  ('1:一中', 1),
#  ('1:經聯保經公司', 1),
#  ('1:家裡 ', 1),
#  ('1:Qisda', 1),
#  ('1:鎮東國小', 1),
#  ('1:普台國小', 1),
#  ('1:高中', 1),
#  ('1:震怡', 1),
#  ('1:華南產險', 1),
#  ('1:台灣富士電機', 1),
#  ('1:達飛通運有限公司', 1),
#  ('1:高雄市文山高中', 1),
#  ('1:野村資訊人員是豬退休人員還有這選項', 1),
#  ('1:樂逸', 1),
#  ('1:豪仁貿易', 1),
#  ('1:優勢', 1),
#  ('1:陽明海運', 1),
#  ('1:智宇生醫股份有限公司', 1),
#  ('1:ddd', 1),
#  ('1:國稅局', 1),
#  ('1:高雄市立大同醫院', 1),
#  ('1:職業公會', 1),
#  ('1:特力屋', 1),
#  ('1:洽成', 1),
#  ('1:原笙', 1),
#  ('1:臺灣高等法院', 1),
#  ('1:研華', 1),
#  ('1:長興材料工業股份有限公司', 1),
#  ('1:金駿營造', 1),
#  ('1:開波企業社', 1),
#  ('1:寶雅物流', 1),
#  ('1:三井住友銀行', 1),
#  ('1:承鋐', 1),
#  ('1:台界化學工業股份有限公司', 1),
#  ('1:自由研究者(接案、寫作)', 1),
#  ('1:修理廠', 1),
#  ('1:龍華', 1),
#  ('1:冠群保經', 1),
#  ('1:化工廠', 1),
#  ('1:旗艦貿易股份有限公司', 1),
#  ('1:核能研究所', 1),
#  ('1:穀得電影有公司', 1),
#  ('1:工業技術研究院', 1),
#  ('1:SUM首福汽車', 1),
#  ('1:新北市政府', 1),
#  ('1:台灣玻璃', 1),
#  ('1:負責人', 1),
#  ('1:一品企業有限公司', 1),
#  ('1:禾馨', 1),
#  ('1:資策會', 1),
#  ('1:視陽光學', 1),
#  ('1:不適用', 1),
#  ('1:愛普科技', 1),
#  ('1:力積電子', 1),
#  ('1:佳音廣告', 1),
#  ('1:漢生實業', 1),
#  ('1:醣基生醫', 1),
#  ('1:北科大 電機所', 1),
#  ('1:美光', 1),
#  ('1:亞拓', 1),
#  ('1:晃誼科技', 1),
#  ('1:城邦', 1),
#  ('1:蓋亞汽車股份有限公司', 1),
#  ('1:茂浤股份有限公司', 1),
#  ('1:精華光學股份有限公司', 1),
#  ('1:昇恆昌', 1),
#  ('1:中油', 1),
#  ('1:金豪記冷凍空調有限公司', 1),
#  ('1:中儀', 1),
#  ('1:豈鑫有限公司', 1),
#  ('1:弘遠交通公司', 1),
#  ('1:台南', 1),
#  ('1:中國電視公司', 1),
#  ('1:亨元實業', 1),
#  ('1:全錄', 1),
#  ('1:桃園基督的教會', 1),
#  ...]

# %%
A032_counter = Counter([x for x in A03 if type(x)==str and x[0]=='2'])
A032_counter.most_common()
# Out:
# [('2:無', 152),
#  ('2:家管', 43),
#  ('2:會計', 43),
#  ('2:業務', 39),
#  ('2:財務部', 29),
#  ('2:業務部', 29),
#  ('2:教師', 27),
#  ('2:學生', 23),
#  ('2:行政', 19),
#  ('2:退休', 18),
#  ('2:管理部', 17),
#  ('2:負責人', 17),
#  ('2:財務', 13),
#  ('2:經理', 12),
#  ('2:總經理室', 11),
#  ('2:採購', 10),
#  ('2:管理', 9),
#  ('2:教務處', 9),
#  ('2:品管', 7),
#  ('2:學務處', 7),
#  ('2:已退休', 7),
#  ('2:職員', 7),
#  ('2:老師', 7),
#  ('2:待業中', 6),
#  ('2:助理', 6),
#  ('2:工程師', 6),
#  ('2:0', 6),
#  ('2:總務處', 6),
#  ('2:研發部', 6),
#  ('2:工程部', 6),
#  ('2:設計部', 6),
#  ('2:自營', 6),
#  ('2:研發', 6),
#  ('2:家', 6),
#  ('2:IT', 5),
#  ('2:退休人士', 5),
#  ('2:設計', 5),
#  ('2:行政部門', 5),
#  ('2:資訊部', 5),
#  ('2:主管', 5),
#  ('2:會計部', 5),
#  ('2:企劃', 5),
#  ('2:營業部', 4),
#  ('2:RD', 4),
#  ('2:門診', 4),
#  ('2:工務部', 4),
#  ('2:秘書室', 4),
#  ('2:數位理財部', 4),
#  ('2:生產部', 4),
#  ('2:總經理', 4),
#  ('2:主任', 4),
#  ('2:自家', 4),
#  ('2:自宅', 4),
#  ('2:行銷', 4),
#  ('2:藥局', 4),
#  ('2:基金事務部', 3),
#  ('2:財會', 3),
#  ('2:人事室', 3),
#  ('2:店長', 3),
#  ('2:銷售', 3),
#  ('2:維修部', 3),
#  ('2:資材部', 3),
#  ('2:工程', 3),
#  ('2:電機系', 3),
#  ('2:家裡', 3),
#  ('2:000', 3),
#  ('2:店員', 3),
#  ('2:存匯', 3),
#  ('2:內勤', 3),
#  ('2:客服', 3),
#  ('2:技術部', 3),
#  ('2:家庭主婦', 3),
#  ('2:no', 3),
#  ('2:總務', 3),
#  ('2:營業', 3),
#  ('2:業務部門', 3),
#  ('2:輔導室', 3),
#  ('2:DCB', 2),
#  ('2:船務', 2),
#  ('2:技師', 2),
#  ('2:行銷策略部', 2),
#  ('2:進出口', 2),
#  ('2:數學科', 2),
#  ('2:總公司', 2),
#  ('2:材料', 2),
#  ('2:主治醫師', 2),
#  ('2:健康中心', 2),
#  ('2:產品暨業務發展策略部', 2),
#  ('2:導遊', 2),
#  ('2:主婦', 2),
#  ('2:護理部', 2),
#  ('2:客服單位', 2),
#  ('2:MIS', 2),
#  ('2:秘書', 2),
#  ('2:包裝部', 2),
#  ('2:院長', 2),
#  ('2:老闆', 2),
#  ('2:社會局', 2),
#  ('2:管家', 2),
#  ('2:文書', 2),
#  ('2:現場', 2),
#  ('2:開發', 2),
#  ('2:品保', 2),
#  ('2:出納', 2),
#  ('2:護理', 2),
#  ('2:基金會計', 2),
#  ('2:自由業', 2),
#  ('2:診所', 2),
#  ('2:法律', 2),
#  ('2:藥師', 2),
#  ('2:行政人員', 2),
#  ('2:護理科', 2),
#  ('2:技術員', 2),
#  ('2:補習班', 2),
#  ('2:資訊室', 2),
#  ('2:包裝', 2),
#  ('2:綜合企劃部', 2),
#  ('2:幼兒園', 2),
#  ('2:n', 2),
#  ('2:技術', 2),
#  ('2:軟體', 2),
#  ('2:自營商', 2),
#  ('2:生產', 2),
#  ('2:資訊處', 2),
#  ('2:營運部', 2),
#  ('2:講師', 2),
#  ('2:none', 2),
#  ('2:品管部', 2),
#  ('2:部門', 2),
#  ('2:製造', 2),
#  ('2:工務', 2),
#  ('2:學齡前', 2),
#  ('2:醫院', 2),
#  ('2:服務部', 2),
#  ('2:專員', 2),
#  ('2:血液透析室', 2),
#  ('2:環保局', 1),
#  ('2:生管', 1),
#  ('2:一等秘書', 1),
#  ('2:通路業務處', 1),
#  ('2:通路事務處', 1),
#  ('2:業務組', 1),
#  ('2:FREELANCER', 1),
#  ('2:技術部門', 1),
#  ('2:SME', 1),
#  ('2:貿易部', 1),
#  ('2:資本市場', 1),
#  ('2:後勤指揮部', 1),
#  ('2:法金', 1),
#  ('2:火力', 1),
#  ('2:檢驗科', 1),
#  ('2:債管部', 1),
#  ('2:系統', 1),
#  ('2:台灣分公司', 1),
#  ('2:訂貨中心', 1),
#  ('2:研究機構', 1),
#  ('2:國際營運處', 1),
#  ('2:國際業務', 1),
#  ('2:na', 1),
#  ('2:工廠', 1),
#  ('2:SALES', 1),
#  ('2:保險部門', 1),
#  ('2:SCM', 1),
#  ('2:專技人員', 1),
#  ('2:secret', 1),
#  ('2:加工股', 1),
#  ('2:機電部', 1),
#  ('2:台中', 1),
#  ('2:im', 1),
#  ('2:退休人士 ', 1),
#  ('2:查核組', 1),
#  ('2:發行部', 1),
#  ('2:Network Management Department', 1),
#  ('2:Instructor', 1),
#  ('2:全權委託投資部', 1),
#  ('2:保留', 1),
#  ('2:農民保險組', 1),
#  ('2:塔山發電廠', 1),
#  ('2:分局', 1),
#  ('2:僑務組', 1),
#  ('2:柴鑽', 1),
#  ('2:專任教師', 1),
#  ('2:設計暨技術平台', 1),
#  ('2:裕信股份有限公司', 1),
#  ('2:護士', 1),
#  ('2:22', 1),
#  ('2:人事行政部', 1),
#  ('2:公', 1),
#  ('2:行政課', 1),
#  ('2:物料部', 1),
#  ('2:tech', 1),
#  ('2:拒答', 1),
#  ('2:法令遵循', 1),
#  ('2:國中部', 1),
#  ('2:成品管理部', 1),
#  ('2:電磁設計部', 1),
#  ('2:發行', 1),
#  ('2:靜宜大學', 1),
#  ('2:機師', 1),
#  ('2:運轉值班', 1),
#  ('2:运营部', 1),
#  ('2:1233', 1),
#  ('2:特約導遊', 1),
#  ('2:技術士', 1),
#  ('2:物理治療', 1),
#  ('2:無職', 1),
#  ('2:電路設計', 1),
#  ('2:製播工程處', 1),
#  ('2:種苗場', 1),
#  ('2:契約行政', 1),
#  ('2:下料', 1),
#  ('2:軟体部', 1),
#  ('2:記帳部', 1),
#  ('2:級任', 1),
#  ('2:營運管理部', 1),
#  ('2:稅務局', 1),
#  ('2:備料', 1),
#  ('2:投資策略', 1),
#  ('2:獸醫師', 1),
#  ('2:稽核室', 1),
#  ('2:公務', 1),
#  ('2:服務', 1),
#  ('2:Project Mgmt', 1),
#  ('2:财务部', 1),
#  ('2:PE', 1),
#  ('2:製造工程', 1),
#  ('2:綜合調度所', 1),
#  ('2:公司', 1),
#  ('2:橅', 1),
#  ('2:外送員', 1),
#  ('2:圖書館', 1),
#  ('2:自動化', 1),
#  ('2:行政 ', 1),
#  ('2:財務經理部', 1),
#  ('2:營二部', 1),
#  ('2:家一一', 1),
#  ('2:研發工程師', 1),
#  ('2:昆蟲系', 1),
#  ('2:家庭醫學科', 1),
#  ('2:招攬', 1),
#  ('2:導師', 1),
#  ('2:設備工程部', 1),
#  ('2:條約法律司', 1),
#  ('2:SG1E', 1),
#  ('2:風管組', 1),
#  ('2:路竹地政', 1),
#  ('2:MegaRAC', 1),
#  ('2:探採事業部企劃室', 1),
#  ('2:疾管署', 1),
#  ('2:供銷部', 1),
#  ('2:行管會', 1),
#  ('2:化妝品應用與管理系', 1),
#  ('2:電信研究院', 1),
#  ('2:工人', 1),
#  ('2:新聞系', 1),
#  ('2:廠務', 1),
#  ('2:自然系', 1),
#  ('2:國中部數學科教師', 1),
#  ('2:車櫃部', 1),
#  ('2:台大分部', 1),
#  ('2:資深辦事員', 1),
#  ('2:診療', 1),
#  ('2:總務室', 1),
#  ('2:燒成課', 1),
#  ('2:北部區行政中心管理二課', 1),
#  ('2:學校', 1),
#  ('2:你說呢？', 1),
#  ('2:領事', 1),
#  ('2:研考科', 1),
#  ('2:製造處工程中心', 1),
#  ('2:桃園分行籌備處', 1),
#  ('2:班導師', 1),
#  ('2:公務部門', 1),
#  ('2:國防部', 1),
#  ('2:集中', 1),
#  ('2:驗證管理部', 1),
#  ('2:數位理財', 1),
#  ('2:业务', 1),
#  ('2:債管', 1),
#  ('2:承保', 1),
#  ('2:分離曲軸股', 1),
#  ('2:平鎮金陵', 1),
#  ('2:市場部', 1),
#  ('2:微生物', 1),
#  ('2:鑄造科', 1),
#  ('2:研究所', 1),
#  ('2:home', 1),
#  ('2:節目部', 1),
#  ('2:輔導處', 1),
#  ('2:恒美窗簾製作', 1),
#  ('2:OP', 1),
#  ('2:仁德郵局儲匯', 1),
#  ('2:醫檢部', 1),
#  ('2:交通部', 1),
#  ('2:SMB', 1),
#  ('2:供應處', 1),
#  ('2:安裝部', 1),
#  ('2:財務金融系', 1),
#  ('2:資訊工程部', 1),
#  ('2:採購部', 1),
#  ('2:EQ', 1),
#  ('2:檢驗', 1),
#  ('2:文件處理', 1),
#  ('2:牙醫', 1),
#  ('2:家務', 1),
#  ('2:PM', 1),
#  ('2:自聘', 1),
#  ('2:檢查局', 1),
#  ('2:會計部門', 1),
#  ('2:估算', 1),
#  ('2:演奏', 1),
#  ('2: NARLabs', 1),
#  ('2:稅務部門', 1),
#  ('2:副首長室', 1),
#  ('2:財務處', 1),
#  ('2:賣場', 1),
#  ('2:股東', 1),
#  ('2:消防', 1),
#  ('2:清潔隊', 1),
#  ('2:無線暨系統方案第二事業處', 1),
#  ('2:資訊科', 1),
#  ('2:出口船務', 1),
#  ('2:病歷室', 1),
#  ('2:技術處', 1),
#  ('2:個人工作室', 1),
#  ('2:財政課', 1),
#  ('2:電子資訊', 1),
#  ('2:鋼筋課', 1),
#  ('2:廠務處', 1),
#  ('2:工程處', 1),
#  ('2:竹南中正店', 1),
#  ('2:業務行銷', 1),
#  ('2:場務部', 1),
#  ('2:雇員', 1),
#  ('2:技術人員', 1),
#  ('2:長庚醫院', 1),
#  ('2:待業', 1),
#  ('2:工業工程', 1),
#  ('2:B00', 1),
#  ('2:Fire', 1),
#  ('2:藝術史學系', 1),
#  ('2:工程單位', 1),
#  ('2:哲學系', 1),
#  ('2:組', 1),
#  ('2:OBGYN', 1),
#  ('2:金融系統部', 1),
#  ('2:MPC', 1),
#  ('2:專利部', 1),
#  ('2:社會司', 1),
#  ('2:厚膜事業部', 1),
#  ('2:BBB', 1),
#  ('2:苓雅分行', 1),
#  ('2:管理單位', 1),
#  ('2:記帳', 1),
#  ('2:北港分公司', 1),
#  ('2:LA', 1),
#  ('2:加值服務技術處', 1),
#  ('2:產品工程部', 1),
#  ('2:人力外派', 1),
#  ('2:打雜部', 1),
#  ('2:CEO', 1),
#  ('2:牙科部', 1),
#  ('2:公共事業群', 1),
#  ('2:記帳員', 1),
#  ('2:國際處', 1),
#  ('2:農務', 1),
#  ('2:brand', 1),
#  ('2:NT', 1),
#  ('2:門市部', 1),
#  ('2:內湖', 1),
#  ('2:企業風險管理處', 1),
#  ('2:裝修', 1),
#  ('2:cs', 1),
#  ('2:文件', 1),
#  ('2:所有', 1),
#  ('2:營建', 1),
#  ('2:倉儲', 1),
#  ('2:總務部', 1),
#  ('2:教學', 1),
#  ('2:內科', 1),
#  ('2:信用卡部', 1),
#  ('2:nil', 1),
#  ('2:實習處', 1),
#  ('2:航運管理科', 1),
#  ('2:攤位', 1),
#  ('2:理財部門', 1),
#  ('2:會計組長', 1),
#  ('2:ICSD', 1),
#  ('2:NB', 1),
#  ('2:customer services ', 1),
#  ('2:數據通信分公司', 1),
#  ('2:出 口部', 1),
#  ('2:財會人員', 1),
#  ('2:財會部', 1),
#  ('2:設計二課', 1),
#  ('2:退休人員', 1),
#  ('2:專任', 1),
#  ('2:受雇律師', 1),
#  ('2:業務客服', 1),
#  ('2:ma', 1),
#  ('2:通路', 1),
#  ('2:骨科', 1),
#  ('2:國軍', 1),
#  ('2:戒護科', 1),
#  ('2:硬體設計中心', 1),
#  ('2:海險部', 1),
#  ('2:WWATS', 1),
#  ('2:第一核能發電廠在', 1),
#  ('2:海外投資部', 1),
#  ('2:applied language ', 1),
#  ('2:品保部', 1),
#  ('2:ＨＲ', 1),
#  ('2:營業分店店長', 1),
#  ('2:高球證經紀人', 1),
#  ('2:研究生', 1),
#  ('2:新隆醫事檢驗所', 1),
#  ('2:保母', 1),
#  ('2:財會部門', 1),
#  ('2:Digital Client Business', 1),
#  ('2:第三股', 1),
#  ('2:國務院', 1),
#  ('2:企像台', 1),
#  ('2:1107測試', 1),
#  ('2:通識中心', 1),
#  ('2:襄理', 1),
#  ('2:執行長室', 1),
#  ('2:門市', 1),
#  ('2:存款', 1),
#  ('2:存匯部門', 1),
#  ('2:老年科', 1),
#  ('2:動力系', 1),
#  ('2:高醫附設醫院', 1),
#  ('2:打雜', 1),
#  ('2:經濟系', 1),
#  ('2:藝術創意產業系', 1),
#  ('2:配向', 1),
#  ('2:教學組', 1),
#  ('2:勞安室', 1),
#  ('2:花蓮廠', 1),
#  ('2:總監', 1),
#  ('2:管制室', 1),
#  ('2:出口部', 1),
#  ('2:Home', 1),
#  ('2:水環部', 1),
#  ('2:管理資訊部', 1),
#  ('2:系統部', 1),
#  ('2:稽核', 1),
#  ('2:電子系', 1),
#  ('2:備餐室', 1),
#  ('2:斗六分行', 1),
#  ('2:屏東營業所', 1),
#  ('2:PTE', 1),
#  ('2:合 檢', 1),
#  ('2:董事長室', 1),
#  ('2:臺中國小', 1),
#  ('2:歷史語言所', 1),
#  ('2:海軍中士', 1),
#  ('2:花藝設計師', 1),
#  ('2:VIP', 1),
#  ('2:通關業務組', 1),
#  ('2:KM', 1),
#  ('2:電腦室', 1),
#  ('2:投資相關部門', 1),
#  ('2:xx', 1),
#  ('2:安全部', 1),
#  ('2:電腦', 1),
#  ('2:行消', 1),
#  ('2:電信工程部', 1),
#  ('2:營運', 1),
#  ('2:廚房', 1),
#  ('2:經紀部', 1),
#  ('2:寶全', 1),
#  ('2:234', 1),
#  ('2:專任導師', 1),
#  ('2:儀電部', 1),
#  ('2:設計研發部', 1),
#  ('2:品設', 1),
#  ('2:國中', 1),
#  ('2:加工', 1),
#  ('2:針織部', 1),
#  ('2:保費部', 1),
#  ('2:東華大學', 1),
#  ('2:計量交易部', 1),
#  ('2:Sales dept.', 1),
#  ('2:建中', 1),
#  ('2:觀音工業區郵局', 1),
#  ('2:ECSE', 1),
#  ('2:業務發展部', 1),
#  ('2:營造部門', 1),
#  ('2:維修部門', 1),
#  ('2:出口', 1),
#  ('2:台北醫學大學', 1),
#  ('2:機關', 1),
#  ('2:密', 1),
#  ('2:秘書長', 1),
#  ('2:資金運用處', 1),
#  ('2:11', 1),
#  ('2:內場', 1),
#  ('2:製造部', 1),
#  ('2:研發部門', 1),
#  ('2:sales', 1),
#  ('2:應用化學系', 1),
#  ('2:債券部', 1),
#  ('2:藥劑部', 1),
#  ('2:電視商品處', 1),
#  ('2:長榮交響樂團', 1),
#  ('2:專案企劃', 1),
#  ('2:國際部', 1),
#  ('2:EHS', 1),
#  ('2:補教老師', 1),
#  ('2:人事', 1),
#  ('2:課員', 1),
#  ('2:銷售員', 1),
#  ('2:製造處', 1),
#  ('2:音樂音效課', 1),
#  ('2:勞保局', 1),
#  ('2:法務', 1),
#  ('2:主', 1),
#  ('2:網頁', 1),
#  ('2:倉庫', 1),
#  ('2:op', 1),
#  ('2:broker', 1),
#  ('2:physical broker', 1),
#  ('2:審計部', 1),
#  ('2:設計部門', 1),
#  ('2:EE', 1),
#  ('2:總台', 1),
#  ('2:總管理處', 1),
#  ('2:永和支局', 1),
#  ('2:永和郵局', 1),
#  ('2:基層', 1),
#  ('2:經濟處', 1),
#  ('2:景觀', 1),
#  ('2:財務室', 1),
#  ('2:電子所', 1),
#  ('2:家醫科', 1),
#  ('2:稅務', 1),
#  ('2:護理師', 1),
#  ('2:壽險資訊部', 1),
#  ('2:planning', 1),
#  ('2:三村國小', 1),
#  ('2:人壽', 1),
#  ('2:海外事業辦公室', 1),
#  ('2:審查', 1),
#  ('2:系統三部', 1),
#  ('2:開發部', 1),
#  ('2:一般', 1),
#  ('2:專案設計部', 1),
#  ('2:稽核處', 1),
#  ('2:射束動力小組', 1),
#  ('2:技術研發', 1),
#  ('2:高屏營運部', 1),
#  ('2:後勤資訊總務', 1),
#  ('2:組長', 1),
#  ('2:營養師', 1),
#  ('2:安親班', 1),
#  ('2:會計室', 1),
#  ('2:買賣藝術品', 1),
#  ('2:清關部', 1),
#  ('2:網路工程師', 1),
#  ('2:實驗室', 1),
#  ('2:倉管', 1),
#  ('2:板橋分局', 1),
#  ('2:工程帥', 1),
#  ('2:急診科', 1),
#  ('2:調度人士', 1),
#  ('2:工安處', 1),
#  ('2:電機處', 1),
#  ('2:海洋中心', 1),
#  ('2:世貿分行', 1),
#  ('2:銷售專員', 1),
#  ('2:生技', 1),
#  ('2:生科系', 1),
#  ('2:勞安', 1),
#  ('2:CE', 1),
#  ('2:electronic', 1),
#  ('2:班主任', 1),
#  ('2:托育', 1),
#  ('2:電商', 1),
#  ('2:工商部', 1),
#  ('2:dj94 ru4', 1),
#  ('2:財政', 1),
#  ('2:商船大副', 1),
#  ('2:技供', 1),
#  ('2:國防', 1),
#  ('2:汽車材料買賣', 1),
#  ('2:營業處', 1),
#  ('2:土開', 1),
#  ('2:財務管理部', 1),
#  ('2:業務人員', 1),
#  ('2:MIC', 1),
#  ('2:中醫藥司', 1),
#  ('2:校護', 1),
#  ('2:設計課', 1),
#  ('2:公教團體', 1),
#  ('2:業務處', 1),
#  ('2:技術人員 ', 1),
#  ('2:共同創辦人', 1),
#  ('2:客務部', 1),
#  ('2:急診醫學部', 1),
#  ('2:保單服務部', 1),
#  ('2:人事處', 1),
#  ('2:儲金', 1),
#  ('2:送貨', 1),
#  ('2:督察組', 1),
#  ('2:機場機坪標', 1),
#  ('2:教職', 1),
#  ('2:台灣區', 1),
#  ('2:業務副總', 1),
#  ('2:SV', 1),
#  ('2:文書科', 1),
#  ('2:東陽通訊處', 1),
#  ('2:牙醫師', 1),
#  ('2:家中', 1),
#  ('2:髮型設計', 1),
#  ('2:Me', 1),
#  ('2:藝術設計', 1),
#  ('2:學務處ㄥ', 1),
#  ('2:電銷', 1),
#  ('2:印務', 1),
#  ('2:大學', 1),
#  ('2:私人機構', 1),
#  ('2:新版萬岳', 1),
#  ('2:資訊主管', 1),
#  ('2:加護病房', 1),
#  ('2:業務員 ', 1),
#  ('2:學生未任職', 1),
#  ('2:職能治療', 1),
#  ('2:OSAT', 1),
#  ('2:航行本部', 1),
#  ('2:影音媒體部', 1),
#  ('2: Taiwan', 1),
#  ('2:專業人員', 1),
#  ('2:品管員', 1),
#  ('2:略', 1),
#  ('2:信用部', 1),
#  ('2:專利一組', 1),
#  ('2:營服部', 1),
#  ('2:教', 1),
#  ('2:家裡 ', 1),
#  ('2:物管', 1),
#  ('2:半導體營業部', 1),
#  ('2:野村資訊人員是豬退休人員還有這選項', 1),
#  ('2:餐飲部', 1),
#  ('2:支局經理', 1),
#  ('2:派遣', 1),
#  ('2:智權部門', 1),
#  ('2:董事長', 1),
#  ('2:ddd', 1),
#  ('2:綜所稅', 1),
#  ('2:護理人員', 1),
#  ('2:復健科', 1),
#  ('2:無 ', 1),
#  ('2:刑事庭', 1),
#  ('2:應用工程師', 1),
#  ('2:揀貨部門', 1),
#  ('2:業二處', 1),
#  ('2:CNC', 1),
#  ('2:自由研究者(接案、寫作)', 1),
#  ('2:龍華', 1),
#  ('2:簽署人', 1),
#  ('2:清水分行', 1),
#  ('2:稽核部', 1),
#  ('2:管理職', 1),
#  ('2:董事', 1),
#  ('2:核能儀器組', 1),
#  ('2:電光系統所', 1),
#  ('2:地政局', 1),
#  ('2:星夜髮廊', 1),
#  ('2:創新科技所', 1),
#  ('2:不適用', 1),
#  ('2:產品開發', 1),
#  ('2:MPE', 1),
#  ('2:碩2生', 1),
#  ('2:一般科', 1),
#  ('2:家居', 1),
#  ('2:注三廠包裝', 1),
#  ('2:松山機場3C營業員', 1),
#  ('2:服務部門', 1),
#  ('2:運輸部', 1),
#  ('2:化學', 1),
#  ('2:新聞部媒資中心', 1),
#  ('2:核四施工處', 1),
#  ('2:虎克資訊', 1),
#  ('2:基因體中心', 1),
#  ('2:投資部', 1),
#  ('2:大隊部', 1),
#  ('2:威合股份有限公司', 1),
#  ('2:櫃檯人員', 1),
#  ('2:雲林縣動植物防疫所', 1),
#  ('2:建設處', 1),
#  ('2:製造三課', 1),
#  ('2:牙科', 1),
#  ('2:人力資源', 1),
#  ('2:operation', 1),
#  ('2:營管部', 1),
#  ('2:洗腎室', 1),
#  ('2:工 程師', 1),
#  ('2:FAE', 1),
#  ('2:製程', 1),
#  ('2:行政組', 1),
#  ('2:設備', 1),
#  ('2:PCB設計', 1),
#  ('2:機料課', 1),
#  ('2:行政部們', 1),
#  ('2:投資策略部', 1),
#  ('2:公家單位', 1),
#  ('2:經紀人', 1),
#  ('2:移民署', 1),
#  ('2:音樂工作室', 1),
#  ('2:纜車中心', 1),
#  ('2:圖書館股長', 1),
#  ('2:政風室', 1),
#  ('2:淡水稽徵所', 1),
#  ('2:推廣教育中心', 1),
#  ('2:共同教育委員會', 1),
#  ('2:資源發展處', 1),
#  ('2:精神科', 1),
#  ('2:才藝老師', 1),
#  ('2:As女鞋花蓮店', 1),
#  ('2:資料控管部', 1),
#  ('2:民政課', 1),
#  ('2:生態保育', 1),
#  ('2:保全', 1),
#  ('2:行政管理處', 1),
#  ('2:Owner', 1),
#  ('2:行政處', 1),
#  ('2:司機員', 1),
#  ('2:台北市船務代理商業同業公會', 1),
#  ('2:服務人', 1),
#  ('2:資材', 1),
#  ('2:放款', 1),
#  ('2:管理處', 1),
#  ('2:承保二科', 1),
#  ('2:電控部', 1),
#  ('2:法學院', 1),
#  ('2:鑄造部', 1),
#  ('2:不提供', 1),
#  ('2:客戶服務部', 1),
#  ('2:陸軍', 1),
#  ('2:高雄市社區關懷協會', 1),
#  ('2:生產計畫', 1),
#  ('2:校長室', 1),
#  ('2:作業服務部', 1),
#  ('2:財務部門', 1),
#  ('2:生醫營運', 1),
#  ('2:企業金融', 1),
#  ('2:事務課', 1),
#  ('2:總行', 1),
#  ('2:日文老師', 1),
#  ('2:日文家教', 1),
#  ('2:大溪珍所', 1),
#  ('2:屏東分行', 1),
#  ('2:高雄辦事處', 1),
#  ('2:個人貸款', 1),
#  ('2:律師', 1),
#  ('2:社會課', 1),
#  ('2:國際商務系', 1),
#  ('2:外勤人員', 1),
#  ('2:通路事業處', 1),
#  ('2:品質保證部', 1),
#  ('2:建築', 1),
#  ('2:一般行政', 1),
#  ('2:技術服務部', 1),
#  ('2:警察局', 1),
#  ('2:新竹分公司', 1),
#  ('2:查帳部', 1),
#  ('2:淡水分行', 1),
#  ('2:文書組', 1),
#  ('2:客戶經營處', 1),
#  ('2:觀光暨行政課', 1),
#  ('2:基層員工', 1),
#  ('2:物流暨倉儲管理部', 1),
#  ('2:mm', 1),
#  ('2:直營店店長', 1)]

# %%
A04_counter = Counter([qans for item in customer_df['A04'] for qans in item])
A04_counter.most_common()
# Out:
# [(4, 669), (5, 359), (3, 299), (2, 160), (1, 35)]

# %%
A05_counter = Counter([qans for item in customer_df['A05'] if str(item)!='nan' for qans in item ])
A05_counter.most_common()
# Out:
# [('2:2', 470),
#  (3, 315),
#  ('1:0', 299),
#  ('2:1', 166),
#  ('2:3', 110),
#  ('2:0', 69),
#  ('1:無', 16),
#  ('2:4', 12),
#  ('2:2人', 11),
#  ('1:1', 7),
#  ('1:2', 7),
#  ('1:未婚', 4),
#  ('1:3', 4),
#  ('2:無', 3),
#  ('2:3人', 3),
#  ('1:單身', 2),
#  ('1:無子女', 2),
#  ('1:０', 2),
#  ('1:子女未成年', 2),
#  ('2:2位', 2),
#  ('2:2女1男', 1),
#  ('2:一子一女', 1),
#  ('2:兩', 1),
#  ('2:7', 1),
#  ('2:1位', 1),
#  ('2:2個', 1),
#  (2, 1),
#  ('2:＿', 1),
#  ('2:ㄉ', 1),
#  ('2:ˊ', 1),
#  ('2:1人', 1),
#  ('2:ˇ', 1),
#  ('1:零', 1),
#  ('2:2小', 1),
#  ('2:ㄅ', 1),
#  ('1:5', 1),
#  ('2:2女', 1),
#  ('1:09', 1),
#  ('1:學齡前', 1)]

# %%
A06_counter = Counter([qans for item in customer_df['A06'] if str(item)!='nan' for qans in item ])
A06_counter.most_common()
# Out:
# [(1, 1421),
#  (2, 23),
#  (3, 15),
#  ('6:非外國人', 13),
#  ('6:本國人', 10),
#  ('6:無', 10),
#  ('6:非外國人士', 7),
#  (4, 4),
#  (5, 3),
#  ('6:退休', 2),
#  ('6:我是本國人', 1),
#  ('6:na', 1),
#  ('6:jno', 1),
#  ('6:非', 1),
#  ('6:我不是外國人', 1),
#  ('6:討口飯吃', 1),
#  ('6:本國', 1),
#  ('6:我是本國人喔', 1),
#  ('6:為本國人', 1),
#  ('6:本國人士', 1),
#  ('6:88454', 1),
#  ('6:0', 1),
#  ('6:no', 1),
#  ('6:000', 1),
#  ('6:台灣人', 1),
#  ('6:非外籍', 1),
#  ('6:本國人...', 1)]

# %%
A07_counter = Counter([qans for item in customer_df['A07'] if str(item)!='nan' for qans in item ])
A07_counter.most_common()
# Out:
# [(1, 1520)]

# %%
A08_counter = Counter([qans for item in customer_df['A08'] if str(item)!='nan' for qans in item ])
A08_counter.most_common()
# Out:
# [(5, 1029),
#  (1, 1003),
#  (3, 784),
#  (4, 300),
#  (2, 128),
#  (6, 122),
#  ('7:購屋', 1),
#  ('7:增加資產', 1),
#  ('7:生活', 1),
#  ('7:儲存教育基金', 1)]

# %%
A09_counter = Counter([qans for item in customer_df['A09'] if str(item)!='nan' for qans in item ])
A09_counter.most_common()
# Out:
# [(1, 1144),
#  (3, 871),
#  (2, 251),
#  (7, 106),
#  (4, 104),
#  (8, 96),
#  (6, 21),
#  (5, 14),
#  ('9:存款', 5),
#  ('9:學齡前', 2),
#  ('9:壓歲錢', 2),
#  ('9:其他', 1),
#  ('9:無', 1),
#  ('9:接案子', 1),
#  ('9:儲蓄', 1),
#  ('9:安家費', 1),
#  ('9:兼職收入', 1),
#  ('9:個人隱私', 1)]

# %%
A10_counter = Counter([qans for item in customer_df['A10'] if str(item)!='nan' for qans in item ])
A10_counter.most_common()
# Out:
# [(3, 773), (2, 472), (1, 151), (4, 107), (5, 29)]

# %%
A11_counter = Counter([qans for item in customer_df['A11'] if str(item)!='nan' for qans in item ])
A11_counter.most_common()
# Out:
# [(2, 703), (1, 578), (3, 235), (4, 11), (5, 6)]

# %%
A12_counter = Counter([qans for item in customer_df['A12'] if str(item)!='nan' for qans in item ])
A12_counter.most_common()
# Out:
# [(1, 1190), (2, 256), (3, 82)]

# %%
A13_counter = Counter([qans for item in customer_df['A13'] if str(item)!='nan' for qans in item ])
A13_counter.most_common()
# Out:
# [(1, 1362), (2, 164)]

# %%
A14_counter = Counter([qans for item in customer_df['A14'] if str(item)!='nan' for qans in item ])
A14_counter.most_common()
# Out:
# [(4, 1464), (1, 25), (3, 18), (2, 13)]

# %%
B01_counter = Counter([qans for item in customer_df['B01'] if str(item)!='nan' for qans in item ])
B01_counter.most_common()
# Out:
# [(4, 586), (5, 570), (3, 270), (2, 67), (1, 30)]

# %%
B02_counter = Counter([qans for item in customer_df['B02'] if str(item)!='nan' for qans in item ])
B02_counter.most_common()
# Out:
# [(1, 1315), (4, 1275), (5, 976), (3, 930), (2, 701)]

# %%
B03_counter = Counter([qans for item in customer_df['B03'] if str(item)!='nan' for qans in item ])
B03_counter.most_common()
# Out:
# [(4, 1244), (5, 1067), (3, 698), (2, 396), (1, 227)]

# %%
B04_counter = Counter([qans for item in customer_df['B04'] if str(item)!='nan' for qans in item ])
B04_counter.most_common()
# Out:
# [(5, 798), (3, 380), (4, 208), (2, 129), (1, 17)]

# %%
B05_counter = Counter([qans for item in customer_df['B05'] if str(item)!='nan' for qans in item ])
B05_counter.most_common()
# Out:
# [(4, 872), (3, 619), (5, 30), (2, 5), (1, 2)]

# %%
B06_counter = Counter([qans for item in customer_df['B06'] if str(item)!='nan' for qans in item ])
B06_counter.most_common()
# Out:
# [(5, 533), (4, 473), (3, 391), (2, 127), (1, 8)]

# %%
B07_counter = Counter([qans for item in customer_df['B07'] if str(item)!='nan' for qans in item ])
B07_counter.most_common()
# Out:
# [(5, 609), (4, 371), (3, 306), (2, 180), (1, 68)]

# %%
for item in customer_df['A05']:
    if type(item) == float:
            print(item)
    #for qan in item:
# Out:
# nan
# nan
